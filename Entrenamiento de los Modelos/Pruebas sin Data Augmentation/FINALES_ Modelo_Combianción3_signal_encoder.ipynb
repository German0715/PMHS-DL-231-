# %% [markdown]
# ####Combinación 1: ECG1, ECG2

# %% [markdown]
# ### Importacion de librerias

# %%
pip install iterative-stratification
# Out:
# Collecting iterative-stratification
#   Downloading iterative_stratification-0.1.7-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from iterative-stratification) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from iterative-stratification) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from iterative-stratification) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->iterative-stratification) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->iterative-stratification) (3.2.0)
# Installing collected packages: iterative-stratification
# Successfully installed iterative-stratification-0.1.7

# %%
pip install wfdb
# Out:
# Collecting wfdb
#   Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb) (3.7.1)
# Requirement already satisfied: numpy>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.23.5)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.5.3)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (2.31.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->wfdb) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2023.11.17)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb) (2.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.16.0)
# Installing collected packages: wfdb
# Successfully installed wfdb-4.1.2

# %%
#LIBERIAS
import os
import h5py
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.io as sio
import re
import wfdb
from tabulate import tabulate
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
import scipy

#model libraries
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from tensorflow import keras
from keras import layers
#from keras.utils import np_utils
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score, confusion_matrix
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import roc_curve, auc
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, ReLU, GlobalMaxPooling1D, Dense, Dropout, Permute, Reshape
import tensorflow as tf
import keras
from keras import models, layers
from keras.layers import concatenate
import tensorflow as tf
import keras
from keras import models, layers


from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, auc, classification_report
from tensorflow.keras.optimizers import Adam
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint


from sklearn.model_selection import StratifiedShuffleSplit
from keras.optimizers import Adam
from sklearn.utils.class_weight import compute_class_weight
from keras.models import Model
from sklearn.metrics import f1_score
import numpy as np
from keras.models import clone_model
from keras.utils import to_categorical
from tensorflow.keras import layers, models, regularizers
from sklearn.model_selection import StratifiedKFold

from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#'/content/gdrive/MyDrive/datos_CONV1.h5'#

# %%
#ACCEDIENDO A LOS DATOS..

#Conexión al drive
data_path_1 = '/content/gdrive/MyDrive/2023 Karol Ardila y Germán Moreno/Code/Señales Preprocesadas/GERMAN/datos_CONV1.h5'
data_path_3 = '/content/gdrive/MyDrive/2023 Karol Ardila y Germán Moreno/Code/Señales Preprocesadas/GERMAN/datos_CONV3.h5'
data_path_5 = '/content/gdrive/MyDrive/2023 Karol Ardila y Germán Moreno/Code/Señales Preprocesadas/GERMAN/datos_CONV5.h5'

# %%
# Crear un diccionario para almacenar los datos cargados
loaded_data_3 = {}

# Cargar los datos desde el archivo H5 y almacenarlos en el diccionario
with h5py.File(data_path_3, 'r') as hf:
    for dataset_name_3 in hf.keys():
        # Obtener el nombre de la variable asociada al conjunto de datos
        variable_name_3 = dataset_name_3

        # Cargar los datos y almacenarlos en el diccionario
        loaded_data_3[variable_name_3] = np.array(hf[variable_name_3])

# %%
# Subdividir los datos 80% para train, 10% validation y 10% test
X_train3 = loaded_data_3['X_train']
y_train3 = loaded_data_3['y_train']

X_val3 = loaded_data_3['X_val']
y_val3 = loaded_data_3['y_val']


X_test3 = loaded_data_3['X_test']
y_test3 = loaded_data_3['y_test']

# %%
print("Tamaño de X_train:", X_train3.shape)
print("Tamaño de y_train:", y_train3.shape)
print("-----------------")
print("Tamaño de X_val:", X_val3.shape)
print("Tamaño de y_val:", y_val3.shape)
print("-----------------")
print("Tamaño de X_test:", X_test3.shape)
print("Tamaño de y_test:", y_test3.shape)
# Out:
# Tamaño de X_train: (534, 75000, 2)
# Tamaño de y_train: (534, 1)
# -----------------
# Tamaño de X_val: (67, 75000, 2)
# Tamaño de y_val: (67, 1)
# -----------------
# Tamaño de X_test: (67, 75000, 2)
# Tamaño de y_test: (67, 1)

# %% [markdown]
# ###PRUEBA 6. MB2 + 5 folds  + Callbacks (Early stopping con 20 é paciencia  + REDUCE + Save) + Dropout = 0.85 + L2 = 0.0005

# %%
samples_per_signal = 75000
num_of_signals = 2


# Definir el valor de regularización L2
l2_reg = 0.0005

input_shape = (samples_per_signal,num_of_signals)
inputs = keras.Input(shape=(input_shape))

x = layers.BatchNormalization()(inputs)


x1 = tf.keras.layers.Conv1D(filters=64, kernel_size=11, strides=5, padding="same", kernel_initializer='he_uniform',kernel_regularizer=regularizers.l2(l2_reg))(x)
x1 = layers.BatchNormalization()(x1)
x1 = layers.Activation("relu")(x1)
x1 = layers.Dropout(0.85)(x1)
x1 = tf.keras.layers.Conv1D(filters=64, kernel_size=11, strides=5, padding="same", kernel_initializer='he_uniform',kernel_regularizer=regularizers.l2(l2_reg))(x1)
x1 = layers.BatchNormalization()(x1)
x1 = layers.Activation("relu")(x1)
y1 = layers.GlobalMaxPooling1D()(x1)

x2 = tf.keras.layers.Conv1D(filters=64, kernel_size=75, strides=5, padding="same", kernel_initializer='he_uniform',kernel_regularizer=regularizers.l2(l2_reg))(x)
x2 = layers.BatchNormalization()(x2)
x2 = layers.Activation("relu")(x2)
x2 = layers.Dropout(0.85)(x2)
x2 = tf.keras.layers.Conv1D(filters=64, kernel_size=75, strides=5, padding="same", kernel_initializer='he_uniform',kernel_regularizer=regularizers.l2(l2_reg))(x2)
x2 = layers.BatchNormalization()(x2)
x2 = layers.Activation("relu")(x2)
y2 = layers.GlobalMaxPooling1D()(x2)

x3 = tf.keras.layers.Conv1D(filters=64, kernel_size=150, strides=5, padding="same", kernel_initializer='he_uniform',kernel_regularizer=regularizers.l2(l2_reg))(x)
x3 = layers.BatchNormalization()(x3)
x3 = layers.Activation("relu")(x3)
x3 = layers.Dropout(0.85)(x3)
x3 = tf.keras.layers.Conv1D(filters=64, kernel_size=150, strides=5, padding="same", kernel_initializer='he_uniform',kernel_regularizer=regularizers.l2(l2_reg))(x3)
x3 = layers.BatchNormalization()(x3)
x3 = layers.Activation("relu")(x3)
y3 = layers.GlobalMaxPooling1D()(x3)

x4 = tf.keras.layers.Conv1D(filters=64, kernel_size=400, strides=5, padding="same", kernel_initializer='he_uniform',kernel_regularizer=regularizers.l2(l2_reg))(x)
x4 = layers.BatchNormalization()(x4)
x4 = layers.Activation("relu")(x4)
x4 = layers.Dropout(0.85)(x4)
x4 = tf.keras.layers.Conv1D(filters=64, kernel_size=400, strides=5, padding="same", kernel_initializer='he_uniform',kernel_regularizer=regularizers.l2(l2_reg))(x4)
x4 = layers.BatchNormalization()(x4)
x4 = layers.Activation("relu")(x4)
y4 = layers.GlobalMaxPooling1D()(x4)

y = concatenate([y1, y2, y3, y4])

#y = layers.Dropout(0.3)(y)

outputs = layers.Dense(1, activation="sigmoid", kernel_initializer='glorot_uniform',kernel_regularizer=regularizers.l2(l2_reg))(y)

model = keras.Model(inputs=inputs, outputs=outputs, name="signal_encoder")

# Diagrama de bloques
keras.utils.plot_model(model, "modelo.png", show_shapes=True)

# Resumen
model.summary()
# Out:
# Model: "signal_encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 75000, 2)]           0         []
#
#  batch_normalization (Batch  (None, 75000, 2)             8         ['input_1[0][0]']
#  Normalization)
#
#  conv1d (Conv1D)             (None, 15000, 64)            1472      ['batch_normalization[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 15000, 64)            9664      ['batch_normalization[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 15000, 64)            19264     ['batch_normalization[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 15000, 64)            51264     ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 15000, 64)            256       ['conv1d[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 15000, 64)            256       ['conv1d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 15000, 64)            256       ['conv1d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 15000, 64)            256       ['conv1d_6[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 15000, 64)            0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  activation_2 (Activation)   (None, 15000, 64)            0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  activation_4 (Activation)   (None, 15000, 64)            0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_6 (Activation)   (None, 15000, 64)            0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 15000, 64)            0         ['activation[0][0]']
#
#  dropout_1 (Dropout)         (None, 15000, 64)            0         ['activation_2[0][0]']
#
#  dropout_2 (Dropout)         (None, 15000, 64)            0         ['activation_4[0][0]']
#
#  dropout_3 (Dropout)         (None, 15000, 64)            0         ['activation_6[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 3000, 64)             45120     ['dropout[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 3000, 64)             307264    ['dropout_1[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 3000, 64)             614464    ['dropout_2[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 3000, 64)             1638464   ['dropout_3[0][0]']
#
#  batch_normalization_2 (Bat  (None, 3000, 64)             256       ['conv1d_1[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 3000, 64)             256       ['conv1d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 3000, 64)             256       ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 3000, 64)             256       ['conv1d_7[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 3000, 64)             0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  activation_3 (Activation)   (None, 3000, 64)             0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_5 (Activation)   (None, 3000, 64)             0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 3000, 64)             0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  global_max_pooling1d (Glob  (None, 64)                   0         ['activation_1[0][0]']
#  alMaxPooling1D)
#
#  global_max_pooling1d_1 (Gl  (None, 64)                   0         ['activation_3[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_2 (Gl  (None, 64)                   0         ['activation_5[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_3 (Gl  (None, 64)                   0         ['activation_7[0][0]']
#  obalMaxPooling1D)
#
#  concatenate (Concatenate)   (None, 256)                  0         ['global_max_pooling1d[0][0]',
#                                                                      'global_max_pooling1d_1[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_2[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_3[0][0]
#                                                                     ']
#
#  dense (Dense)               (None, 1)                    257       ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 2689289 (10.26 MB)
# Trainable params: 2688261 (10.25 MB)
# Non-trainable params: 1028 (4.02 KB)
# __________________________________________________________________________________________________

# %%
# Compila el modelo
model.compile(
    optimizer= keras.optimizers.Adam(learning_rate=0.001),
    loss= keras.losses.BinaryCrossentropy(),
    metrics=['accuracy'])

# %%
# Combinar datos para k-fold
X_combined = np.concatenate((X_train3, X_val3), axis=0)
y_combined = np.concatenate((y_train3, y_val3), axis=0)

n_folds = 5

#Para guardar los mejores accuracys
fold_train_accuracies = []
fold_val_accuracies = []
fold_test_accuracies = []
fold_precisions = []
fold_recalls = []
fold_f1_scores = []
fold_roc_aucs = []
fold_score = []

# StratifiedKFold
stratkf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=42)

initial_weights = None

# Entrenamiento con k-fold estratificado
for fold, (train_index, val_index) in enumerate(stratkf.split(X_combined, y_combined)):
    X_train_fold, X_val_fold = X_combined[train_index], X_combined[val_index]
    y_train_fold, y_val_fold = y_combined[train_index], y_combined[val_index]


    # Guardar los pesos iniciales en la primera iteración
    if initial_weights is None:
        initial_weights = model.get_weights()

    # Restablecer pesos a los valores iniciales
    model.set_weights(initial_weights)

    # Compilar el modelo
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss=keras.losses.BinaryCrossentropy(),
        metrics=['accuracy']
    )

    # Entrenamiento con callbacks para guardar el mejor modelo
    callbacks = [
        EarlyStopping(monitor='val_loss',patience=20,verbose=1, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss',factor=0.2,patience=4,verbose=1),
        ModelCheckpoint(filepath=f"best_model_fold3_P3_{fold + 1}.keras", save_best_only=True)]

    print(f"\nEntrenando Fold {fold + 1}...")

    history = model.fit(
        X_train_fold, y_train_fold,
        epochs=99999,
        batch_size=128,
        validation_data=(X_val_fold, y_val_fold),
        callbacks=callbacks
    )

    #METRICAS DE EVALUACION DEL MODELO
    best_model = load_model(f"best_model_fold3_P3_{fold + 1}.keras")

    # Evaluar el mejor modelo en el conjunto de prueba

    test_loss, test_accuracy = best_model.evaluate(X_test3, y_test3)
    fold_test_accuracies.append(test_accuracy)

    # Evaluar el mejor modelo en el conjunto de entrenamiento
    train_loss, train_accuracy = best_model.evaluate(X_train_fold, y_train_fold)
    fold_train_accuracies.append(train_accuracy)

    # Evaluar el mejor modelo en el conjunto de validación
    val_loss, val_accuracy = best_model.evaluate(X_val_fold, y_val_fold)
    fold_val_accuracies.append(val_accuracy)


    # Obtener las predicciones en el conjunto de prueba
    y_pred_probs = best_model.predict(X_test3)

    # Convertir las probabilidades a clases binarias basadas en un umbral (PUEDE SER EL ERROR)
    threshold = 0.5
    y_pred_binary = (y_pred_probs > threshold).astype(int)

    # Convertir las etiquetas a clases binarias
    y_true_binary = (y_test3 > 0.5).astype(int)

    # Calcular métricas
    accuracy = accuracy_score(y_true_binary, y_pred_binary)
    precision = precision_score(y_true_binary, y_pred_binary)
    recall = recall_score(y_true_binary, y_pred_binary)
    f1 = f1_score(y_true_binary, y_pred_binary)
    roc_auc = roc_auc_score(y_true_binary, y_pred_probs)
    conf_matrix = confusion_matrix(y_true_binary, y_pred_binary, labels=[1, 0])

    fold_train_accuracies.append(train_accuracy)
    fold_val_accuracies.append(val_accuracy)
    fold_test_accuracies.append(test_accuracy)
    fold_precisions.append(precision)
    fold_recalls.append(recall)
    fold_f1_scores.append(f1)
    fold_roc_aucs.append(roc_auc)



    # Extraer los valores de TP, FP, FN y TN de la matriz de confusión
    TP = conf_matrix[0, 0]  # True Positives
    FP = conf_matrix[0, 1]  # False Positives
    FN = conf_matrix[1, 0]  # False Negatives
    TN = conf_matrix[1, 1]  # True Negatives

    # Calcular el score del challenge
    score = (TP + TN) / (TP + TN + FP + (5 * FN))
    fold_score.append(score)


    print("\n")
    print("----------------------------------------------")
    print(f" METRICAS DE EVALUACIÓN PARA EL MODELO")
    print("----------------------------------------------")
    print(f'Accuracy on test set: {test_accuracy * 100:.5f}%')
    print(f'Loss on test set: {test_loss * 100:.5f}%')
    print(f'Precision on test set: {precision * 100:.5f}%')
    print(f'Recall on test set: {recall * 100:.5f}%')
    print(f'F1 Score on test set: {f1 * 100:.5f}%')
    print(f'ROC AUC score on test set: {roc_auc * 100:.5f}')
    print(f'El Score oficial del Challenge es: {score * 100:.5f}')
    #######
    print("\n")
    print("----------------------------------------------")
    print(" REPORTE DE MÉTRICAS CON CLASES BALANCEADAS PARA EL MODELO")
    print("----------------------------------------------")
    report=classification_report(y_true_binary,y_pred_binary)
    print(report)


    #######
    print("\n")
    print("----------------------------------------------")
    print(" GRÁFICAS DE EVALUACIÓN")
    print("----------------------------------------------")
    # Graficar curvas de pérdida y precisión
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title('Loss Curves')
    plt.show()
    print("\n")
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title('Accuracy Curves')
    plt.show()
    print("\n")
    # Plotear la matriz de confusión
    disp = ConfusionMatrixDisplay(conf_matrix)
    disp.plot(cmap=plt.cm.Blues, values_format='d')
    plt.title('Matriz de Confusión')
    plt.show()
    print("\n")
    # Curva ROC
    fpr, tpr, thresholds = roc_curve(y_true_binary, y_pred_probs)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(8, 8))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.5f})'.format(roc_auc))
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.show()


print("\n")
print("----------------------------------------------")
print(" METRICAS DE EVALUACIÓN FINALES EN CADA FOLD")
print("----------------------------------------------")
print("\n")
print(" PARA ENTRENAMIENTO ")
print('El accuracy de cada fold es: ',fold_train_accuracies)
Media_TRAIN = np.mean(fold_train_accuracies)
print(f'La Media del accuracy de los k fols es: {Media_TRAIN}')
Desv_std_TRAIN = np.std(fold_train_accuracies)
print(f'La Desviación Estandar del accuracy de los k fols es: {Desv_std_TRAIN}')

Min_TRAIN = Media_TRAIN - Desv_std_TRAIN
Max_TRAIN = Media_TRAIN + Desv_std_TRAIN
print(f'El accuracy mínimo es: {Min_TRAIN}')
print(f'El accuracy máximo es: {Max_TRAIN}')

print("\n")
print(" PARA VALIDACIÓN ")
print('El accuracy de cada fold es: ',fold_val_accuracies)
Media_VAL = np.mean(fold_val_accuracies)
print(f'La Media del accuracy de los k fols es: {Media_VAL}')
Desv_std_VAL = np.std(fold_val_accuracies)
print(f'La Desviación Estandar del accuracy de los k fols es: {Desv_std_VAL}')

Min_VAL = Media_VAL - Desv_std_VAL
Max_VAL = Media_VAL + Desv_std_VAL
print(f'El accuracy mínimo es: {Min_VAL}')
print(f'El accuracy máximo es: {Max_VAL}')

print("\n")
print(" PARA TESTEO ")
print('El accuracy de cada fold es: ',fold_test_accuracies)
Media_TEST= np.mean(fold_test_accuracies)
print(f'La Media del accuracy de los k fols es: {Media_TEST}')
Desv_std_TEST = np.std(fold_test_accuracies)
print(f'La Desviación Estandar del accuracy de los k fols es: {Desv_std_TEST}')

Min_TEST = Media_TEST - Desv_std_TEST
Max_TEST = Media_TEST + Desv_std_TEST
print(f'El accuracy mínimo es: {Min_TEST}')
print(f'El accuracy máximo es: {Max_TEST}')


print("\n")
print(" PARA LA MÉTRICA DE PRECISIÓN ")
print('La precisión cada fold es: ',fold_precisions)
mean_precision = np.mean(fold_precisions)
print(f'La Media de la precisión de los k fols es: {mean_precision}')
std_precision = np.std(fold_precisions)
print(f'La Desviación Estandar de la precisión de los k fols es: {std_precision}')
Min_precision = mean_precision - std_precision
Max_precision = mean_precision + std_precision
print(f'La precisión mínima es: {Min_precision}')
print(f'La precisión máxima es: {Max_precision}')


print("\n")
print(" PARA LA MÉTRICA DE RECALL ")
print('El recall de cada fold es: ',fold_recalls)
mean_recall = np.mean(fold_recalls)
print(f'La Media del recall de los k fols es: {mean_recall}')
std_recall = np.std(fold_recalls)
print(f'La Desviación Estandar del recall de los k fols es: {std_recall}')
Min_recall = mean_recall - std_recall
Max_recall = mean_recall + std_recall
print(f'El Recall mínimo es: {Min_recall}')
print(f'El Recall máximo es: {Max_recall}')


print("\n")
print(" PARA LA MÉTRICA DE F1 SCORE ")
print('El F1 SCORE de cada fold es: ',fold_f1_scores)
mean_f1_score = np.mean(fold_f1_scores)
print(f'La Media del F1 SCORE de los k fols es: {mean_f1_score}')
std_f1_score = np.std(fold_f1_scores)
print(f'La Desviación Estandar del F1 SCORE de los k fols es: {std_f1_score}')
Min_f1_score = mean_f1_score - std_f1_score
Max_f1_score = mean_f1_score + std_f1_score
print(f'El F1 SCORE mínimo es: {Min_f1_score}')
print(f'El F1 SCORE máximo es: {Max_f1_score}')


print("\n")
print(" PARA EL ROC SCORE ")
print('El ROC SCORE de cada fold es: ',fold_roc_aucs)
mean_roc_auc = np.mean(fold_roc_aucs)
print(f'La Media del ROC SCORE de los k fols es: {mean_roc_auc}')
std_roc_auc = np.std(fold_roc_aucs)
print(f'La Desviación Estandar del ROC SCORE de los k fols es: {std_roc_auc}')
Min_roc_auc = mean_roc_auc - std_roc_auc
Max_roc_auc = mean_roc_auc + std_roc_auc
print(f'El ROC SCORE mínimo es: {Min_roc_auc}')
print(f'El ROC SCORE máximo es: {Max_roc_auc}')


print("\n")
print(" PARA EL SCORE DEL PHYSIONET")
print('El SCORE de cada fold es: ',fold_score)
mean_score = np.mean(fold_score)
print(f'La Media del SCORE de los k fols es: {mean_score}')
std_score = np.std(fold_score)
print(f'La Desviación Estandar del SCORE de los k fols es: {std_score}')
Min_score = mean_score - std_score
Max_score = mean_score + std_score
print(f'El SCORE mínimo es: {Min_score}')
print(f'El SCORE máximo es: {Max_score}')
# Out:
# Entrenando Fold 1...
# Epoch 1/99999
# 4/4 [==============================] - 127s 21s/step - loss: 3.5005 - accuracy: 0.5104 - val_loss: 3.0134 - val_accuracy: 0.6364 - lr: 0.0010
# Epoch 2/99999
# 4/4 [==============================] - 14s 4s/step - loss: 2.2482 - accuracy: 0.6333 - val_loss: 4.1135 - val_accuracy: 0.6198 - lr: 0.0010
# Epoch 3/99999
# 4/4 [==============================] - 14s 4s/step - loss: 2.0481 - accuracy: 0.5854 - val_loss: 14.0120 - val_accuracy: 0.6198 - lr: 0.0010
# Epoch 4/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.6536 - accuracy: 0.6375 - val_loss: 8.4937 - val_accuracy: 0.6198 - lr: 0.0010
# Epoch 5/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.4852 - accuracy: 0.5833
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 4/4 [==============================] - 14s 4s/step - loss: 1.4852 - accuracy: 0.5833 - val_loss: 9.0197 - val_accuracy: 0.6198 - lr: 0.0010
# Epoch 6/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.4457 - accuracy: 0.6646 - val_loss: 7.1565 - val_accuracy: 0.6198 - lr: 2.0000e-04
# Epoch 7/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.3689 - accuracy: 0.6625 - val_loss: 5.0643 - val_accuracy: 0.6198 - lr: 2.0000e-04
# Epoch 8/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.3267 - accuracy: 0.6792 - val_loss: 3.5393 - val_accuracy: 0.6281 - lr: 2.0000e-04
# Epoch 9/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.3686 - accuracy: 0.6458
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 4/4 [==============================] - 14s 4s/step - loss: 1.3686 - accuracy: 0.6458 - val_loss: 3.1156 - val_accuracy: 0.6281 - lr: 2.0000e-04
# Epoch 10/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2381 - accuracy: 0.6708 - val_loss: 2.8927 - val_accuracy: 0.6281 - lr: 4.0000e-05
# Epoch 11/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2388 - accuracy: 0.7042 - val_loss: 2.7108 - val_accuracy: 0.6281 - lr: 4.0000e-05
# Epoch 12/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2496 - accuracy: 0.6896 - val_loss: 2.5362 - val_accuracy: 0.6364 - lr: 4.0000e-05
# Epoch 13/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.3217 - accuracy: 0.6604 - val_loss: 2.3861 - val_accuracy: 0.6364 - lr: 4.0000e-05
# Epoch 14/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2797 - accuracy: 0.6792 - val_loss: 2.2328 - val_accuracy: 0.6364 - lr: 4.0000e-05
# Epoch 15/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1681 - accuracy: 0.7042 - val_loss: 2.1001 - val_accuracy: 0.6364 - lr: 4.0000e-05
# Epoch 16/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2027 - accuracy: 0.7042 - val_loss: 1.9974 - val_accuracy: 0.6364 - lr: 4.0000e-05
# Epoch 17/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2985 - accuracy: 0.6708 - val_loss: 1.9036 - val_accuracy: 0.6364 - lr: 4.0000e-05
# Epoch 18/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.
99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1242 - accuracy: 0.7271 - val_loss: 1.2797 - val_accuracy: 0.6529 - lr: 1.2800e-08
# Epoch 144/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1423 - accuracy: 0.7208 - val_loss: 1.2798 - val_accuracy: 0.6529 - lr: 1.2800e-08
# Epoch 145/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.2186 - accuracy: 0.7063
# Epoch 145: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# 4/4 [==============================] - 14s 4s/step - loss: 1.2186 - accuracy: 0.7063 - val_loss: 1.2798 - val_accuracy: 0.6529 - lr: 1.2800e-08
# Epoch 146/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1573 - accuracy: 0.7063 - val_loss: 1.2798 - val_accuracy: 0.6529 - lr: 2.5600e-09
# Epoch 147/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2016 - accuracy: 0.7146 - val_loss: 1.2797 - val_accuracy: 0.6529 - lr: 2.5600e-09
# Epoch 148/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1808 - accuracy: 0.7312 - val_loss: 1.2797 - val_accuracy: 0.6529 - lr: 2.5600e-09
# Epoch 149/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1747 - accuracy: 0.7167
# Epoch 149: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1747 - accuracy: 0.7167 - val_loss: 1.2798 - val_accuracy: 0.6529 - lr: 2.5600e-09
# Epoch 150/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.0947 - accuracy: 0.7458 - val_loss: 1.2798 - val_accuracy: 0.6529 - lr: 5.1200e-10
# Epoch 151/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2141 - accuracy: 0.6729 - val_loss: 1.2798 - val_accuracy: 0.6529 - lr: 5.1200e-10
# Epoch 152/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1941 - accuracy: 0.7208 - val_loss: 1.2798 - val_accuracy: 0.6529 - lr: 5.1200e-10
# Epoch 153/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1756 - accuracy: 0.6938
# Epoch 153: ReduceLROnPlateau reducing learning rate to 1.0240001069306004e-10.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1756 - accuracy: 0.6938 - val_loss: 1.2797 - val_accuracy: 0.6529 - lr: 5.1200e-10
# Epoch 154/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1131 - accuracy: 0.7354 - val_loss: 1.2797 - val_accuracy: 0.6529 - lr: 1.0240e-10
# Epoch 155/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1832 - accuracy: 0.6896 - val_loss: 1.2797 - val_accuracy: 0.6529 - lr: 1.0240e-10
# Epoch 156/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1207 - accuracy: 0.7229 - val_loss: 1.2797 - val_accuracy: 0.6529 - lr: 1.0240e-10
# Epoch 157/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1858 - accuracy: 0.7063 - val_loss: 1.2797 - val_accuracy: 0.6529 - lr: 1.0240e-10
# Epoch 158/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1475 - accuracy: 0.7396 - val_loss: 1.2797 - val_accuracy: 0.6529 - lr: 1.0240e-10
# Epoch 159/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1310 - accuracy: 0.7250 - val_loss: 1.2797 - val_accuracy: 0.6529 - lr: 1.0240e-10
# Epoch 160/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1052 - accuracy: 0.7396
# Epoch 160: ReduceLROnPlateau reducing learning rate to 2.0480002416167767e-11.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1052 - accuracy: 0.7396 - val_loss: 1.2797 - val_accuracy: 0.6529 - lr: 1.0240e-10
# Epoch 161/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1606 - accuracy: 0.7312 - val_loss: 1.2797 - val_accuracy: 0.6529 - lr: 2.0480e-11
# Epoch 162/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1169 - accuracy: 0.7229 - val_loss: 1.2797 - val_accuracy: 0.6529 - lr: 2.0480e-11
# Epoch 163/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1261 - accuracy: 0.7104 - val_loss: 1.2797 - val_accuracy: 0.6529 - lr: 2.0480e-11
# Epoch 164/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1587 - accuracy: 0.7188
# Epoch 164: ReduceLROnPlateau reducing learning rate to 4.096000622011431e-12.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1587 - accuracy: 0.7188 - val_loss: 1.2797 - val_accuracy: 0.6529 - lr: 2.0480e-11
# Epoch 165/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1999 - accuracy: 0.6854 - val_loss: 1.2797 - val_accuracy: 0.6529 - lr: 4.0960e-12
# Epoch 166/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1640 - accuracy: 0.7312 - val_loss: 1.2797 - val_accuracy: 0.6529 - lr: 4.0960e-12
# Epoch 167/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1160 - accuracy: 0.7479 - val_loss: 1.2796 - val_accuracy: 0.6529 - lr: 4.0960e-12
# Epoch 168/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1740 - accuracy: 0.7042
# Epoch 168: ReduceLROnPlateau reducing learning rate to 8.192000897078167e-13.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1740 - accuracy: 0.7042 - val_loss: 1.2796 - val_accuracy: 0.6529 - lr: 4.0960e-12
# Epoch 169/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1420 - accuracy: 0.7354 - val_loss: 1.2796 - val_accuracy: 0.6529 - lr: 8.1920e-13
# Epoch 170/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1071 - accuracy: 0.7563 - val_loss: 1.2796 - val_accuracy: 0.6529 - lr: 8.1920e-13
# Epoch 171/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1643 - accuracy: 0.7229 - val_loss: 1.2796 - val_accuracy: 0.6529 - lr: 8.1920e-13
# Epoch 172/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1788 - accuracy: 0.7125
# Epoch 172: ReduceLROnPlateau reducing learning rate to 1.6384001360475466e-13.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1788 - accuracy: 0.7125 - val_loss: 1.2796 - val_accuracy: 0.6529 - lr: 8.1920e-13
# Epoch 173/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1803 - accuracy: 0.7104 - val_loss: 1.2795 - val_accuracy: 0.6529 - lr: 1.6384e-13
# Epoch 174/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1644 - accuracy: 0.7146 - val_loss: 1.2795 - val_accuracy: 0.6529 - lr: 1.6384e-13
# Epoch 175/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1155 - accuracy: 0.7208 - val_loss: 1.2795 - val_accuracy: 0.6529 - lr: 1.6384e-13
# Epoch 176/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1407 - accuracy: 0.7188 - val_loss: 1.2795 - val_accuracy: 0.6529 - lr: 1.6384e-13
# Epoch 177/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2510 - accuracy: 0.7083 - val_loss: 1.2794 - val_accuracy: 0.6529 - lr: 1.6384e-13
# Epoch 178/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.0366 - accuracy: 0.7708 - val_loss: 1.2794 - val_accuracy: 0.6529 - lr: 1.6384e-13
# Epoch 179/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1699 - accuracy: 0.7021 - val_loss: 1.2794 - val_accuracy: 0.6529 - lr: 1.6384e-13
# Epoch 180/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1661 - accuracy: 0.7083 - val_loss: 1.2794 - val_accuracy: 0.6529 - lr: 1.6384e-13
# Epoch 181/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1852 - accuracy: 0.6958
# Epoch 181: ReduceLROnPlateau reducing learning rate to 3.2768002178849846e-14.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1852 - accuracy: 0.6958 - val_loss: 1.2794 - val_accuracy: 0.6529 - lr: 1.6384e-13
# Epoch 182/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.0929 - accuracy: 0.7437 - val_loss: 1.2794 - val_accuracy: 0.6529 - lr: 3.2768e-14
# Epoch 183/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1459 - accuracy: 0.7229 - val_loss: 1.2794 - val_accuracy: 0.6529 - lr: 3.2768e-14
# Epoch 184/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1232 - accuracy: 0.7208 - val_loss: 1.2794 - val_accuracy: 0.6529 - lr: 3.2768e-14
# Epoch 185/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1835 - accuracy: 0.6875
# Epoch 185: ReduceLROnPlateau reducing learning rate to 6.553600300244697e-15.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1835 - accuracy: 0.6875 - val_loss: 1.2794 - val_accuracy: 0.6529 - lr: 3.2768e-14
# Epoch 186/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.0998 - accuracy: 0.7333 - val_loss: 1.2794 - val_accuracy: 0.6529 - lr: 6.5536e-15
# Epoch 187/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2023 - accuracy: 0.7083 - val_loss: 1.2794 - val_accuracy: 0.6529 - lr: 6.5536e-15
# Epoch 188/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.0910 - accuracy: 0.7271 - val_loss: 1.2794 - val_accuracy: 0.6529 - lr: 6.5536e-15
# Epoch 189/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1628 - accuracy: 0.7208
# Epoch 189: ReduceLROnPlateau reducing learning rate to 1.3107200431082805e-15.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1628 - accuracy: 0.7208 - val_loss: 1.2794 - val_accuracy: 0.6529 - lr: 6.5536e-15
# Epoch 190/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1301 - accuracy: 0.7063 - val_loss: 1.2794 - val_accuracy: 0.6529 - lr: 1.3107e-15
# Epoch 191/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1562 - accuracy: 0.7146 - val_loss: 1.2794 - val_accuracy: 0.6529 - lr: 1.3107e-15
# Epoch 192/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1048 - accuracy: 0.7375 - val_loss: 1.2794 - val_accuracy: 0.6529 - lr: 1.3107e-15
# Epoch 193/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1082 - accuracy: 0.7396
# Epoch 193: ReduceLROnPlateau reducing learning rate to 2.6214401285682084e-16.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1082 - accuracy: 0.7396 - val_loss: 1.2794 - val_accuracy: 0.6529 - lr: 1.3107e-15
# Epoch 194/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1796 - accuracy: 0.7104 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 2.6214e-16
# Epoch 195/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1199 - accuracy: 0.7208 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 2.6214e-16
# Epoch 196/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.0962 - accuracy: 0.7667 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 2.6214e-16
# Epoch 197/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1985 - accuracy: 0.7042
# Epoch 197: ReduceLROnPlateau reducing learning rate to 5.2428803630155353e-17.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1985 - accuracy: 0.7042 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 2.6214e-16
# Epoch 198/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2353 - accuracy: 0.6896 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 5.2429e-17
# Epoch 199/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1834 - accuracy: 0.7188 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 5.2429e-17
# Epoch 200/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1637 - accuracy: 0.7167 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 5.2429e-17
# Epoch 201/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2002 - accuracy: 0.7125 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 5.2429e-17
# Epoch 202/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1313 - accuracy: 0.7271
# Epoch 202: ReduceLROnPlateau reducing learning rate to 1.0485760990728867e-17.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1313 - accuracy: 0.7271 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 5.2429e-17
# Epoch 203/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1237 - accuracy: 0.7188 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 1.0486e-17
# Epoch 204/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1391 - accuracy: 0.7063 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 1.0486e-17
# Epoch 205/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1119 - accuracy: 0.7250 - val_loss: 1.2792 - val_accuracy: 0.6529 - lr: 1.0486e-17
# Epoch 206/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1059 - accuracy: 0.7417
# Epoch 206: ReduceLROnPlateau reducing learning rate to 2.097152165058549e-18.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1059 - accuracy: 0.7417 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 1.0486e-17
# Epoch 207/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1368 - accuracy: 0.7437 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 2.0972e-18
# Epoch 208/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1667 - accuracy: 0.7104 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 2.0972e-18
# Epoch 209/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2329 - accuracy: 0.7146 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 2.0972e-18
# Epoch 210/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1379 - accuracy: 0.7250
# Epoch 210: ReduceLROnPlateau reducing learning rate to 4.19430449555322e-19.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1379 - accuracy: 0.7250 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 2.0972e-18
# Epoch 211/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1359 - accuracy: 0.7250 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 4.1943e-19
# Epoch 212/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1772 - accuracy: 0.7229 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 4.1943e-19
# Epoch 213/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1484 - accuracy: 0.7083 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 4.1943e-19
# Epoch 214/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1566 - accuracy: 0.7125
# Epoch 214: ReduceLROnPlateau reducing learning rate to 8.388609197901593e-20.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1566 - accuracy: 0.7125 - val_loss: 1.2792 - val_accuracy: 0.6529 - lr: 4.1943e-19
# Epoch 215/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1869 - accuracy: 0.7250 - val_loss: 1.2792 - val_accuracy: 0.6529 - lr: 8.3886e-20
# Epoch 216/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1342 - accuracy: 0.7167 - val_loss: 1.2792 - val_accuracy: 0.6529 - lr: 8.3886e-20
# Epoch 217/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1476 - accuracy: 0.7063 - val_loss: 1.2792 - val_accuracy: 0.6529 - lr: 8.3886e-20
# Epoch 218/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1657 - accuracy: 0.7083 - val_loss: 1.2792 - val_accuracy: 0.6529 - lr: 8.3886e-20
# Epoch 219/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1229 - accuracy: 0.7312
# Epoch 219: ReduceLROnPlateau reducing learning rate to 1.6777218395803187e-20.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1229 - accuracy: 0.7312 - val_loss: 1.2792 - val_accuracy: 0.6529 - lr: 8.3886e-20
# Epoch 220/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1103 - accuracy: 0.7542 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 1.6777e-20
# Epoch 221/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1663 - accuracy: 0.7271 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 1.6777e-20
# Epoch 222/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1480 - accuracy: 0.6938 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 1.6777e-20
# Epoch 223/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1565 - accuracy: 0.7167
# Epoch 223: ReduceLROnPlateau reducing learning rate to 3.3554436145371517e-21.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1565 - accuracy: 0.7167 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 1.6777e-20
# Epoch 224/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1928 - accuracy: 0.7354 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 3.3554e-21
# Epoch 225/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1152 - accuracy: 0.7188 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 3.3554e-21
# Epoch 226/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1770 - accuracy: 0.7021 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 3.3554e-21
# Epoch 227/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1652 - accuracy: 0.7208
# Epoch 227: ReduceLROnPlateau reducing learning rate to 6.710887229074304e-22.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1652 - accuracy: 0.7208 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 3.3554e-21
# Epoch 228/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1192 - accuracy: 0.7354 - val_loss: 1.2792 - val_accuracy: 0.6529 - lr: 6.7109e-22
# Epoch 229/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1716 - accuracy: 0.7104 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 6.7109e-22
# Epoch 230/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1239 - accuracy: 0.7271 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 6.7109e-22
# Epoch 231/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1508 - accuracy: 0.7229
# Epoch 231: ReduceLROnPlateau reducing learning rate to 1.3421774862045392e-22.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1508 - accuracy: 0.7229 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 6.7109e-22
# Epoch 232/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1662 - accuracy: 0.7188 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 1.3422e-22
# Epoch 233/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1730 - accuracy: 0.7250 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 1.3422e-22
# Epoch 234/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1078 - accuracy: 0.7271 - val_loss: 1.2792 - val_accuracy: 0.6529 - lr: 1.3422e-22
# Epoch 235/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1179 - accuracy: 0.7312Restoring model weights from the end of the best epoch: 215.
#
# Epoch 235: ReduceLROnPlateau reducing learning rate to 2.684355073383274e-23.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1179 - accuracy: 0.7312 - val_loss: 1.2793 - val_accuracy: 0.6529 - lr: 1.3422e-22
# Epoch 235: early stopping
# 3/3 [==============================] - 4s 344ms/step - loss: 1.0202 - accuracy: 0.7910
# 15/15 [==============================] - 4s 263ms/step - loss: 0.9950 - accuracy: 0.8104
# 4/4 [==============================] - 3s 1s/step - loss: 1.2792 - accuracy: 0.6529
# 3/3 [==============================] - 1s 255ms/step
#
#
# ----------------------------------------------
#  METRICAS DE EVALUACIÓN PARA EL MODELO
# ----------------------------------------------
# Accuracy on test set: 79.10448%
# Loss on test set: 102.02181%
# Precision on test set: 69.23077%
# Recall on test set: 75.00000%
# F1 Score on test set: 72.00000%
# ROC AUC score on test set: 85.17442
# El Score oficial del Challenge es: 53.53535
#
#
# ----------------------------------------------
#  REPORTE DE MÉTRICAS CON CLASES BALANCEADAS PARA EL MODELO
# ----------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83        43
#            1       0.69      0.75      0.72        24
#
#     accuracy                           0.79        67
#    macro avg       0.77      0.78      0.78        67
# weighted avg       0.80      0.79      0.79        67
#
#
#
# ----------------------------------------------
#  GRÁFICAS DE EVALUACIÓN
# ----------------------------------------------
# Entrenando Fold 2...
# Epoch 1/99999
# 4/4 [==============================] - 71s 21s/step - loss: 3.0954 - accuracy: 0.5509 - val_loss: 4.0740 - val_accuracy: 0.6750 - lr: 0.0010
# Epoch 2/99999
# 4/4 [==============================] - 14s 4s/step - loss: 2.1100 - accuracy: 0.5925 - val_loss: 5.6896 - val_accuracy: 0.6167 - lr: 0.0010
# Epoch 3/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.6677 - accuracy: 0.6403 - val_loss: 13.9731 - val_accuracy: 0.6167 - lr: 0.0010
# Epoch 4/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.5934 - accuracy: 0.6071 - val_loss: 6.4202 - val_accuracy: 0.6083 - lr: 0.0010
# Epoch 5/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.4088 - accuracy: 0.6362
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 4/4 [==============================] - 14s 4s/step - loss: 1.4088 - accuracy: 0.6362 - val_loss: 9.1583 - val_accuracy: 0.6167 - lr: 0.0010
# Epoch 6/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.4848 - accuracy: 0.7006 - val_loss: 6.8830 - val_accuracy: 0.6167 - lr: 2.0000e-04
# Epoch 7/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.3886 - accuracy: 0.6653 - val_loss: 3.9705 - val_accuracy: 0.6083 - lr: 2.0000e-04
# Epoch 8/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.3347 - accuracy: 0.6175 - val_loss: 2.7979 - val_accuracy: 0.5917 - lr: 2.0000e-04
# Epoch 9/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2160 - accuracy: 0.6507 - val_loss: 2.7451 - val_accuracy: 0.5917 - lr: 2.0000e-04
# Epoch 10/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2826 - accuracy: 0.6632 - val_loss: 2.7981 - val_accuracy: 0.6000 - lr: 2.0000e-04
# Epoch 11/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2776 - accuracy: 0.7380 - val_loss: 2.1850 - val_accuracy: 0.6417 - lr: 2.0000e-04
# Epoch 12/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2352 - accuracy: 0.6861 - val_loss: 1.7327 - val_accuracy: 0.7083 - lr: 2.0000e-04
# Epoch 13/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1666 - accuracy: 0.7110 - val_loss: 1.5809 - val_accuracy: 0.7333 - lr: 2.0000e-04
# Epoch 14/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2036 - accuracy: 0.6778 - val_loss: 1.5598 - val_accuracy: 0.7250 - lr: 2.0000e-04
# Epoch 15/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1799 - accuracy: 0.7027 - val_loss: 1.5725 - val_accuracy: 0.7250 - lr: 2.0000e-04
# Epoch 16/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1608 - accuracy: 0.7173 - val_loss: 1.5623 - val_accuracy: 0.7250 - lr: 2.0000e-04
# Epoch 17/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2192 - accuracy: 0.6861 - val_loss: 1.5364 - val_accuracy: 0.7083 - lr: 2.0000e-04
# Epoch 18/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1329 - accuracy: 0.7380 - val_loss: 1.5264 - val_accuracy: 0.7083 - lr: 2.0000e-04
# Epoch 19/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1251 - accuracy: 0.7380 - val_loss: 1.4951 - val_accuracy: 0.7167 - lr: 2.0000e-04
# Epoch 20/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1327 - accuracy: 0.7152 - val_loss: 1.4781 - val_accuracy: 0.6833 - lr: 2.0000e-04
# Epoch 21/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1869 - accuracy: 0.7006 - val_loss: 1.4322 - val_accuracy: 0.6833 - lr: 2.0000e-04
# Epoch 22/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1106 - accuracy: 0.7401 - val_loss: 1.4103 - val_accuracy: 0.6917 - lr: 2.0000e-04
# Epoch 23/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1524 - accuracy: 0.7235 - val_loss: 1.4057 - val_accuracy: 0.6917 - lr: 2.0000e-04
# Epoch 24/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1110 - accuracy: 0.7360 - val_loss: 1.4136 - val_accuracy: 0.6833 - lr: 2.0000e-04
# Epoch 25/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1289 - accuracy: 0.7526 - val_loss: 1.4149 - val_accuracy: 0.6833 - lr: 2.0000e-04
# Epoch 26/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1441 - accuracy: 0.7173 - val_loss: 1.4108 - val_accuracy: 0.7000 - lr: 2.0000e-04
# Epoch 27/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1997 - accuracy: 0.7048
# Epoch 27: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1997 - accuracy: 0.7048 - val_loss: 1.4595 - val_accuracy: 0.6583 - lr: 2.0000e-04
# Epoch 28/99999
# ...
# Epoch 124/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2420 - accuracy: 0.6944 - val_loss: 1.3057 - val_accuracy: 0.6750 - lr: 6.4000e-08
# Epoch 125/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1967 - accuracy: 0.6861 - val_loss: 1.3057 - val_accuracy: 0.6750 - lr: 6.4000e-08
# Epoch 126/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2044 - accuracy: 0.7069 - val_loss: 1.3057 - val_accuracy: 0.6750 - lr: 6.4000e-08
# Epoch 127/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1232 - accuracy: 0.7214
# Epoch 127: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1232 - accuracy: 0.7214 - val_loss: 1.3057 - val_accuracy: 0.6750 - lr: 6.4000e-08
# Epoch 128/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1839 - accuracy: 0.6694 - val_loss: 1.3057 - val_accuracy: 0.6750 - lr: 1.2800e-08
# Epoch 129/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2331 - accuracy: 0.6965 - val_loss: 1.3056 - val_accuracy: 0.6750 - lr: 1.2800e-08
# Epoch 130/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2165 - accuracy: 0.6778 - val_loss: 1.3056 - val_accuracy: 0.6750 - lr: 1.2800e-08
# Epoch 131/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1763 - accuracy: 0.6923
# Epoch 131: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1763 - accuracy: 0.6923 - val_loss: 1.3055 - val_accuracy: 0.6750 - lr: 1.2800e-08
# Epoch 132/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2371 - accuracy: 0.6798 - val_loss: 1.3055 - val_accuracy: 0.6750 - lr: 2.5600e-09
# Epoch 133/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1794 - accuracy: 0.7131 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 2.5600e-09
# Epoch 134/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1414 - accuracy: 0.7006 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 2.5600e-09
# Epoch 135/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1794 - accuracy: 0.6778 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 2.5600e-09
# Epoch 136/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1840 - accuracy: 0.6923 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 2.5600e-09
# Epoch 137/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2126 - accuracy: 0.7006 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 2.5600e-09
# Epoch 138/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1621 - accuracy: 0.6819
# Epoch 138: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1621 - accuracy: 0.6819 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 2.5600e-09
# Epoch 139/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1624 - accuracy: 0.6861 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 5.1200e-10
# Epoch 140/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1713 - accuracy: 0.6861 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 5.1200e-10
# Epoch 141/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1941 - accuracy: 0.6965 - val_loss: 1.3055 - val_accuracy: 0.6750 - lr: 5.1200e-10
# Epoch 142/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.2072 - accuracy: 0.7027
# Epoch 142: ReduceLROnPlateau reducing learning rate to 1.0240001069306004e-10.
# 4/4 [==============================] - 14s 4s/step - loss: 1.2072 - accuracy: 0.7027 - val_loss: 1.3055 - val_accuracy: 0.6750 - lr: 5.1200e-10
# Epoch 143/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2031 - accuracy: 0.7027 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 1.0240e-10
# Epoch 144/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2058 - accuracy: 0.6944 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 1.0240e-10
# Epoch 145/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1791 - accuracy: 0.6819 - val_loss: 1.3055 - val_accuracy: 0.6750 - lr: 1.0240e-10
# Epoch 146/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.2029 - accuracy: 0.6881
# Epoch 146: ReduceLROnPlateau reducing learning rate to 2.0480002416167767e-11.
# 4/4 [==============================] - 14s 4s/step - loss: 1.2029 - accuracy: 0.6881 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 1.0240e-10
# Epoch 147/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1676 - accuracy: 0.7027 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 2.0480e-11
# Epoch 148/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1668 - accuracy: 0.7235 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 2.0480e-11
# Epoch 149/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1913 - accuracy: 0.7069 - val_loss: 1.3053 - val_accuracy: 0.6750 - lr: 2.0480e-11
# Epoch 150/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.2117 - accuracy: 0.6881
# Epoch 150: ReduceLROnPlateau reducing learning rate to 4.096000622011431e-12.
# 4/4 [==============================] - 14s 4s/step - loss: 1.2117 - accuracy: 0.6881 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 2.0480e-11
# Epoch 151/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2467 - accuracy: 0.6736 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 4.0960e-12
# Epoch 152/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2526 - accuracy: 0.6861 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 4.0960e-12
# Epoch 153/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2144 - accuracy: 0.6881 - val_loss: 1.3053 - val_accuracy: 0.6750 - lr: 4.0960e-12
# Epoch 154/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2280 - accuracy: 0.6798 - val_loss: 1.3053 - val_accuracy: 0.6750 - lr: 4.0960e-12
# Epoch 155/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2535 - accuracy: 0.7006 - val_loss: 1.3053 - val_accuracy: 0.6750 - lr: 4.0960e-12
# Epoch 156/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2113 - accuracy: 0.6840 - val_loss: 1.3053 - val_accuracy: 0.6750 - lr: 4.0960e-12
# Epoch 157/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1910 - accuracy: 0.6985 - val_loss: 1.3052 - val_accuracy: 0.6750 - lr: 4.0960e-12
# Epoch 158/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.2070 - accuracy: 0.7006
# Epoch 158: ReduceLROnPlateau reducing learning rate to 8.192000897078167e-13.
# 4/4 [==============================] - 14s 4s/step - loss: 1.2070 - accuracy: 0.7006 - val_loss: 1.3053 - val_accuracy: 0.6750 - lr: 4.0960e-12
# Epoch 159/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1818 - accuracy: 0.7006 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 8.1920e-13
# Epoch 160/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2703 - accuracy: 0.6590 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 8.1920e-13
# Epoch 161/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1786 - accuracy: 0.6881 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 8.1920e-13
# Epoch 162/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1597 - accuracy: 0.7152
# Epoch 162: ReduceLROnPlateau reducing learning rate to 1.6384001360475466e-13.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1597 - accuracy: 0.7152 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 8.1920e-13
# Epoch 163/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1827 - accuracy: 0.7069 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 1.6384e-13
# Epoch 164/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2106 - accuracy: 0.6674 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 1.6384e-13
# Epoch 165/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1779 - accuracy: 0.7089 - val_loss: 1.3055 - val_accuracy: 0.6750 - lr: 1.6384e-13
# Epoch 166/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.2529 - accuracy: 0.6757
# Epoch 166: ReduceLROnPlateau reducing learning rate to 3.2768002178849846e-14.
# 4/4 [==============================] - 14s 4s/step - loss: 1.2529 - accuracy: 0.6757 - val_loss: 1.3055 - val_accuracy: 0.6750 - lr: 1.6384e-13
# Epoch 167/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.2330 - accuracy: 0.7006 - val_loss: 1.3056 - val_accuracy: 0.6750 - lr: 3.2768e-14
# Epoch 168/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1854 - accuracy: 0.6944 - val_loss: 1.3056 - val_accuracy: 0.6750 - lr: 3.2768e-14
# Epoch 169/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1862 - accuracy: 0.6923 - val_loss: 1.3056 - val_accuracy: 0.6750 - lr: 3.2768e-14
# Epoch 170/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.2007 - accuracy: 0.6965
# Epoch 170: ReduceLROnPlateau reducing learning rate to 6.553600300244697e-15.
# 4/4 [==============================] - 14s 4s/step - loss: 1.2007 - accuracy: 0.6965 - val_loss: 1.3056 - val_accuracy: 0.6750 - lr: 3.2768e-14
# Epoch 171/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1704 - accuracy: 0.6965 - val_loss: 1.3055 - val_accuracy: 0.6750 - lr: 6.5536e-15
# Epoch 172/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1393 - accuracy: 0.7048 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 6.5536e-15
# Epoch 173/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1746 - accuracy: 0.6902 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 6.5536e-15
# Epoch 174/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.2035 - accuracy: 0.6944
# Epoch 174: ReduceLROnPlateau reducing learning rate to 1.3107200431082805e-15.
# 4/4 [==============================] - 14s 4s/step - loss: 1.2035 - accuracy: 0.6944 - val_loss: 1.3053 - val_accuracy: 0.6750 - lr: 6.5536e-15
# Epoch 175/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1988 - accuracy: 0.6715 - val_loss: 1.3053 - val_accuracy: 0.6750 - lr: 1.3107e-15
# Epoch 176/99999
# 4/4 [==============================] - 14s 4s/step - loss: 1.1684 - accuracy: 0.6923 - val_loss: 1.3054 - val_accuracy: 0.6750 - lr: 1.3107e-15
# Epoch 177/99999
# 4/4 [==============================] - ETA: 0s - loss: 1.1776 - accuracy: 0.7069Restoring model weights from the end of the best epoch: 157.
# 4/4 [==============================] - 14s 4s/step - loss: 1.1776 - accuracy: 0.7069 - val_loss: 1.3053 - val_accuracy: 0.6750 - lr: 1.3107e-15
# Epoch 177: early stopping
# 3/3 [==============================] - 1s 149ms/step - loss: 1.0109 - accuracy: 0.7910
# 16/16 [==============================] - 4s 247ms/step - loss: 1.0405 - accuracy: 0.7568
# 4/4 [==============================] - 1s 243ms/step - loss: 1.3052 - accuracy: 0.6750
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7e93a438bd00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 1s 253ms/step
#
#
# ----------------------------------------------
#  METRICAS DE EVALUACIÓN PARA EL MODELO
# ----------------------------------------------
# Accuracy on test set: 79.10448%
# Loss on test set: 101.08880%
# Precision on test set: 75.00000%
# Recall on test set: 62.50000%
# F1 Score on test set: 68.18182%
# ROC AUC score on test set: 85.36822
# El Score oficial del Challenge es: 60.91954
#
#
# ----------------------------------------------
#  REPORTE DE MÉTRICAS CON CLASES BALANCEADAS PARA EL MODELO
# ----------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84        43
#            1       0.75      0.62      0.68        24
#
#     accuracy                           0.79        67
#    macro avg       0.78      0.75      0.76        67
# weighted avg       0.79      0.79      0.79        67
#
#
#
# ----------------------------------------------
#  GRÁFICAS DE EVALUACIÓN
# ----------------------------------------------
# ----------------------------------------------
#  METRICAS DE EVALUACIÓN FINALES EN CADA FOLD
# ----------------------------------------------
#
#
#  PARA ENTRENAMIENTO
# El accuracy de cada fold es:  [0.8104166388511658, 0.8104166388511658, 0.8191268444061279, 0.8191268444061279, 0.7567567825317383, 0.7567567825317383, 0.8440748453140259, 0.8440748453140259, 0.7567567825317383, 0.7567567825317383]
# La Media del accuracy de los k fols es: 0.7974263787269592
# La Desviación Estandar del accuracy de los k fols es: 0.034996481574800245
# El accuracy mínimo es: 0.7624298971521589
# El accuracy máximo es: 0.8324228603017595
#
#
#  PARA VALIDACIÓN
# El accuracy de cada fold es:  [0.6528925895690918, 0.6528925895690918, 0.6583333611488342, 0.6583333611488342, 0.6166666746139526, 0.6166666746139526, 0.675000011920929, 0.675000011920929, 0.675000011920929, 0.675000011920929]
# La Media del accuracy de los k fols es: 0.6555785298347473
# La Desviación Estandar del accuracy de los k fols es: 0.021369715862648145
# El accuracy mínimo es: 0.6342088139720992
# El accuracy máximo es: 0.6769482456973954
#
#
#  PARA TESTEO
# El accuracy de cada fold es:  [0.7910447716712952, 0.7910447716712952, 0.746268630027771, 0.746268630027771, 0.8059701323509216, 0.8059701323509216, 0.7611940503120422, 0.7611940503120422, 0.7910447716712952, 0.7910447716712952]
# La Media del accuracy de los k fols es: 0.779104471206665
# La Desviación Estandar del accuracy de los k fols es: 0.021935728579818844
# El accuracy mínimo es: 0.7571687426268462
# El accuracy máximo es: 0.8010401997864839
#
#
#  PARA LA MÉTRICA DE PRECISIÓN
# La precisión cada fold es:  [0.6923076923076923, 0.6060606060606061, 0.7037037037037037, 0.7, 0.75]
# La Media de la precisión de los k fols es: 0.6904144004144005
# La Desviación Estandar de la precisión de los k fols es: 0.04677195774260763
# La precisión mínima es: 0.6436424426717928
# La precisión máxima es: 0.7371863581570082
#
#
#  PARA LA MÉTRICA DE RECALL
# El recall de cada fold es:  [0.75, 0.8333333333333334, 0.7916666666666666, 0.5833333333333334, 0.625]
# La Media del recall de los k fols es: 0.7166666666666667
# La Desviación Estandar del recall de los k fols es: 0.09646530752325187
# El Recall mínimo es: 0.6202013591434148
# El Recall máximo es: 0.8131319741899186
#
#
#  PARA LA MÉTRICA DE F1 SCORE
# El F1 SCORE de cada fold es:  [0.7199999999999999, 0.7017543859649124, 0.7450980392156864, 0.6363636363636365, 0.6818181818181818]
# La Media del F1 SCORE de los k fols es: 0.6970068486724834
# La Desviación Estandar del F1 SCORE de los k fols es: 0.03680293881233557
# El F1 SCORE mínimo es: 0.6602039098601479
# El F1 SCORE máximo es: 0.733809787484819
#
#
#  PARA EL ROC SCORE
# El ROC SCORE de cada fold es:  [0.8517441860465116, 0.8110465116279071, 0.8585271317829458, 0.7577519379844961, 0.8536821705426356]
# La Media del ROC SCORE de los k fols es: 0.8265503875968992
# La Desviación Estandar del ROC SCORE de los k fols es: 0.0383848150549312
# El ROC SCORE mínimo es: 0.7881655725419681
# El ROC SCORE máximo es: 0.8649352026518304
#
#
#  PARA EL SCORE DEL PHYSIONET
# El SCORE de cada fold es:  [0.5353535353535354, 0.42016806722689076, 0.5454545454545454, 0.5604395604395604, 0.6091954022988506]
# La Media del SCORE de los k fols es: 0.5341222221546765
# La Desviación Estandar del SCORE de los k fols es: 0.06236035885116901
# El SCORE mínimo es: 0.4717618633035075
# El SCORE máximo es: 0.5964825810058455
