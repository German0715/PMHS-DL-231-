# %% [markdown]
# ####Combinación ALL

# %% [markdown]
# ### Importacion de librerias

# %%
pip install iterative-stratification
# Out:
# Collecting iterative-stratification
#   Downloading iterative_stratification-0.1.7-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from iterative-stratification) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from iterative-stratification) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from iterative-stratification) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->iterative-stratification) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->iterative-stratification) (3.2.0)
# Installing collected packages: iterative-stratification
# Successfully installed iterative-stratification-0.1.7

# %%
pip install wfdb
# Out:
# Collecting wfdb
#   Downloading wfdb-4.1.2-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: SoundFile>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (0.12.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from wfdb) (3.7.1)
# Requirement already satisfied: numpy>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.23.5)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.5.3)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from wfdb) (2.31.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wfdb) (1.11.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.2.2->wfdb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->wfdb) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.8.1->wfdb) (2023.11.17)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from SoundFile>=0.10.0->wfdb) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->SoundFile>=0.10.0->wfdb) (2.21)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->wfdb) (1.16.0)
# Installing collected packages: wfdb
# Successfully installed wfdb-4.1.2

# %%
#LIBERIAS
import os
import h5py
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.io as sio
import re
import wfdb
from tabulate import tabulate
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
import scipy

#model libraries
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from tensorflow import keras
from keras import layers
#from keras.utils import np_utils
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score, confusion_matrix
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import roc_curve, auc
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, ReLU, GlobalMaxPooling1D, Dense, Dropout, Permute, Reshape
import tensorflow as tf
import keras
from keras import models, layers
from keras.layers import concatenate
import tensorflow as tf
import keras
from keras import models, layers


from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, auc, classification_report
from tensorflow.keras.optimizers import Adam
from keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint


from sklearn.model_selection import StratifiedShuffleSplit
from keras.optimizers import Adam
from sklearn.utils.class_weight import compute_class_weight
from keras.models import Model
from sklearn.metrics import f1_score
import numpy as np
from keras.models import clone_model
from keras.utils import to_categorical
from tensorflow.keras import layers, models, regularizers
from sklearn.model_selection import StratifiedKFold

from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#'/content/gdrive/MyDrive/datos_CONV1.h5'#

# %%
#ACCEDIENDO A LOS DATOS..

#Conexión al drive
data_path_1 = '/content/gdrive/MyDrive/2023 Karol Ardila y Germán Moreno/Code/Señales Preprocesadas/GERMAN/datos_CONV1.h5'
data_path_3 = '/content/gdrive/MyDrive/2023 Karol Ardila y Germán Moreno/Code/Señales Preprocesadas/GERMAN/datos_CONV3.h5'
data_path_5 = '/content/gdrive/MyDrive/2023 Karol Ardila y Germán Moreno/Code/Señales Preprocesadas/GERMAN/datos_CONV5.h5'
data_path_ALL = '/content/gdrive/MyDrive/2023 Karol Ardila y Germán Moreno/Code/Señales Preprocesadas/GERMAN/datos_CONV_ALL.h5'

# %%
# Crear un diccionario para almacenar los datos cargados
loaded_data_ALL = {}

# Cargar los datos desde el archivo H5 y almacenarlos en el diccionario
with h5py.File(data_path_ALL, 'r') as hf:
    for dataset_name_ALL in hf.keys():
        # Obtener el nombre de la variable asociada al conjunto de datos
        variable_name_ALL = dataset_name_ALL

        # Cargar los datos y almacenarlos en el diccionario
        loaded_data_ALL[variable_name_ALL] = np.array(hf[variable_name_ALL])

# %%
# Subdividir los datos 80% para train, 10% validation y 10% test
X_trainALL = loaded_data_ALL['X_train']
y_trainALL = loaded_data_ALL['y_train']

X_valALL = loaded_data_ALL['X_val']
y_valALL = loaded_data_ALL['y_val']


X_testALL = loaded_data_ALL['X_test']
y_testALL = loaded_data_ALL['y_test']

# %%
print("Tamaño de X_train:", X_trainALL.shape)
print("Tamaño de y_train:", y_trainALL.shape)
print("-----------------")
print("Tamaño de X_val:", X_valALL.shape)
print("Tamaño de y_val:", y_valALL.shape)
print("-----------------")
print("Tamaño de X_test:", X_testALL.shape)
print("Tamaño de y_test:", y_testALL.shape)
# Out:
# Tamaño de X_train: (600, 75000, 4)
# Tamaño de y_train: (600, 1)
# -----------------
# Tamaño de X_val: (75, 75000, 4)
# Tamaño de y_val: (75, 1)
# -----------------
# Tamaño de X_test: (75, 75000, 4)
# Tamaño de y_test: (75, 1)

# %% [markdown]
# ###PRUEBA 5. MB + 5 folds  + Callbacks (Early stopping con 20 é paciencia  + REDUCE + Save) + Dropout = 0.85 + L2 = 0.0005

# %%
samples_per_signal = 75000
num_of_signals = 4


# Definir el valor de regularización L2
l2_reg = 0.0005

input_shape = (samples_per_signal,num_of_signals)
inputs = keras.Input(shape=(input_shape))

x = layers.BatchNormalization()(inputs)


x1 = tf.keras.layers.Conv1D(filters=64, kernel_size=50, strides=5, padding="same", kernel_initializer='he_uniform',kernel_regularizer=regularizers.l2(l2_reg))(x)
x1 = layers.BatchNormalization()(x1)
x1 = layers.Activation("relu")(x1)
x1 = layers.Dropout(0.85)(x1)
x1 = tf.keras.layers.Conv1D(filters=64, kernel_size=50, strides=5, padding="same", kernel_initializer='he_uniform',kernel_regularizer=regularizers.l2(l2_reg))(x1)
x1 = layers.BatchNormalization()(x1)
x1 = layers.Activation("relu")(x1)
y1 = layers.GlobalMaxPooling1D()(x1)

x2 = tf.keras.layers.Conv1D(filters=64, kernel_size=100, strides=5, padding="same", kernel_initializer='he_uniform',kernel_regularizer=regularizers.l2(l2_reg))(x)
x2 = layers.BatchNormalization()(x2)
x2 = layers.Activation("relu")(x2)
x2 = layers.Dropout(0.85)(x2)
x2 = tf.keras.layers.Conv1D(filters=64, kernel_size=100, strides=5, padding="same", kernel_initializer='he_uniform',kernel_regularizer=regularizers.l2(l2_reg))(x2)
x2 = layers.BatchNormalization()(x2)
x2 = layers.Activation("relu")(x2)
y2 = layers.GlobalMaxPooling1D()(x2)

x3 = tf.keras.layers.Conv1D(filters=64, kernel_size=200, strides=5, padding="same", kernel_initializer='he_uniform',kernel_regularizer=regularizers.l2(l2_reg))(x)
x3 = layers.BatchNormalization()(x3)
x3 = layers.Activation("relu")(x3)
x3 = layers.Dropout(0.85)(x3)
x3 = tf.keras.layers.Conv1D(filters=64, kernel_size=200, strides=5, padding="same", kernel_initializer='he_uniform',kernel_regularizer=regularizers.l2(l2_reg))(x3)
x3 = layers.BatchNormalization()(x3)
x3 = layers.Activation("relu")(x3)
y3 = layers.GlobalMaxPooling1D()(x3)

x4 = tf.keras.layers.Conv1D(filters=64, kernel_size=400, strides=5, padding="same", kernel_initializer='he_uniform',kernel_regularizer=regularizers.l2(l2_reg))(x)
x4 = layers.BatchNormalization()(x4)
x4 = layers.Activation("relu")(x4)
x4 = layers.Dropout(0.85)(x4)
x4 = tf.keras.layers.Conv1D(filters=64, kernel_size=400, strides=5, padding="same", kernel_initializer='he_uniform',kernel_regularizer=regularizers.l2(l2_reg))(x4)
x4 = layers.BatchNormalization()(x4)
x4 = layers.Activation("relu")(x4)
y4 = layers.GlobalMaxPooling1D()(x4)

y = concatenate([y1, y2, y3, y4])

#y = layers.Dropout(0.3)(y)

outputs = layers.Dense(1, activation="sigmoid", kernel_initializer='glorot_uniform',kernel_regularizer=regularizers.l2(l2_reg))(y)

model = keras.Model(inputs=inputs, outputs=outputs, name="signal_encoder")

# Diagrama de bloques
keras.utils.plot_model(model, "modelo.png", show_shapes=True)

# Resumen
model.summary()
# Out:
# Model: "signal_encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 75000, 4)]           0         []
#
#  batch_normalization (Batch  (None, 75000, 4)             16        ['input_1[0][0]']
#  Normalization)
#
#  conv1d (Conv1D)             (None, 15000, 64)            12864     ['batch_normalization[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 15000, 64)            25664     ['batch_normalization[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 15000, 64)            51264     ['batch_normalization[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 15000, 64)            102464    ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 15000, 64)            256       ['conv1d[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 15000, 64)            256       ['conv1d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 15000, 64)            256       ['conv1d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 15000, 64)            256       ['conv1d_6[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 15000, 64)            0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  activation_2 (Activation)   (None, 15000, 64)            0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  activation_4 (Activation)   (None, 15000, 64)            0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_6 (Activation)   (None, 15000, 64)            0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout (Dropout)           (None, 15000, 64)            0         ['activation[0][0]']
#
#  dropout_1 (Dropout)         (None, 15000, 64)            0         ['activation_2[0][0]']
#
#  dropout_2 (Dropout)         (None, 15000, 64)            0         ['activation_4[0][0]']
#
#  dropout_3 (Dropout)         (None, 15000, 64)            0         ['activation_6[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 3000, 64)             204864    ['dropout[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 3000, 64)             409664    ['dropout_1[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 3000, 64)             819264    ['dropout_2[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 3000, 64)             1638464   ['dropout_3[0][0]']
#
#  batch_normalization_2 (Bat  (None, 3000, 64)             256       ['conv1d_1[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 3000, 64)             256       ['conv1d_3[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 3000, 64)             256       ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 3000, 64)             256       ['conv1d_7[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 3000, 64)             0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  activation_3 (Activation)   (None, 3000, 64)             0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_5 (Activation)   (None, 3000, 64)             0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 3000, 64)             0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  global_max_pooling1d (Glob  (None, 64)                   0         ['activation_1[0][0]']
#  alMaxPooling1D)
#
#  global_max_pooling1d_1 (Gl  (None, 64)                   0         ['activation_3[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_2 (Gl  (None, 64)                   0         ['activation_5[0][0]']
#  obalMaxPooling1D)
#
#  global_max_pooling1d_3 (Gl  (None, 64)                   0         ['activation_7[0][0]']
#  obalMaxPooling1D)
#
#  concatenate (Concatenate)   (None, 256)                  0         ['global_max_pooling1d[0][0]',
#                                                                      'global_max_pooling1d_1[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_2[0][0]
#                                                                     ',
#                                                                      'global_max_pooling1d_3[0][0]
#                                                                     ']
#
#  dense (Dense)               (None, 1)                    257       ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 3266833 (12.46 MB)
# Trainable params: 3265801 (12.46 MB)
# Non-trainable params: 1032 (4.03 KB)
# __________________________________________________________________________________________________

# %%
# Compila el modelo
model.compile(
    optimizer= keras.optimizers.Adam(learning_rate=0.001),
    loss= keras.losses.BinaryCrossentropy(),
    metrics=['accuracy'])

# %%
# Combinar datos para k-fold
X_combined = np.concatenate((X_trainALL, X_valALL), axis=0)
y_combined = np.concatenate((y_trainALL, y_valALL), axis=0)

n_folds = 5

#Para guardar los mejores accuracys
fold_train_accuracies = []
fold_val_accuracies = []
fold_test_accuracies = []
fold_precisions = []
fold_recalls = []
fold_f1_scores = []
fold_roc_aucs = []
fold_score = []

# StratifiedKFold
stratkf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=42)

initial_weights = None

# Entrenamiento con k-fold estratificado
for fold, (train_index, val_index) in enumerate(stratkf.split(X_combined, y_combined)):
    X_train_fold, X_val_fold = X_combined[train_index], X_combined[val_index]
    y_train_fold, y_val_fold = y_combined[train_index], y_combined[val_index]


    # Guardar los pesos iniciales en la primera iteración
    if initial_weights is None:
        initial_weights = model.get_weights()

    # Restablecer pesos a los valores iniciales
    model.set_weights(initial_weights)

    # Compilar el modelo
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss=keras.losses.BinaryCrossentropy(),
        metrics=['accuracy']
    )

    # Entrenamiento con callbacks para guardar el mejor modelo
    callbacks = [
        EarlyStopping(monitor='val_loss',patience=20,verbose=1, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss',factor=0.2,patience=4,verbose=1),
        ModelCheckpoint(filepath=f"best_model_fold3_P2_{fold + 1}.keras", save_best_only=True)]

    print(f"\nEntrenando Fold {fold + 1}...")

    history = model.fit(
        X_train_fold, y_train_fold,
        epochs=999999,
        batch_size=128,
        validation_data=(X_val_fold, y_val_fold),
        callbacks=callbacks
    )

    #METRICAS DE EVALUACION DEL MODELO
    best_model = load_model(f"best_model_fold3_P2_{fold + 1}.keras")

    # Evaluar el mejor modelo en el conjunto de prueba

    test_loss, test_accuracy = best_model.evaluate(X_testALL, y_testALL)
    fold_test_accuracies.append(test_accuracy)

    # Evaluar el mejor modelo en el conjunto de entrenamiento
    train_loss, train_accuracy = best_model.evaluate(X_train_fold, y_train_fold)
    fold_train_accuracies.append(train_accuracy)

    # Evaluar el mejor modelo en el conjunto de validación
    val_loss, val_accuracy = best_model.evaluate(X_val_fold, y_val_fold)
    fold_val_accuracies.append(val_accuracy)


    # Obtener las predicciones en el conjunto de prueba
    y_pred_probs = best_model.predict(X_testALL)

    # Convertir las probabilidades a clases binarias basadas en un umbral (PUEDE SER EL ERROR)
    threshold = 0.5
    y_pred_binary = (y_pred_probs > threshold).astype(int)

    # Convertir las etiquetas a clases binarias
    y_true_binary = (y_testALL > 0.5).astype(int)

    # Calcular métricas
    accuracy = accuracy_score(y_true_binary, y_pred_binary)
    precision = precision_score(y_true_binary, y_pred_binary)
    recall = recall_score(y_true_binary, y_pred_binary)
    f1 = f1_score(y_true_binary, y_pred_binary)
    roc_auc = roc_auc_score(y_true_binary, y_pred_probs)
    conf_matrix = confusion_matrix(y_true_binary, y_pred_binary, labels=[1, 0])

    fold_train_accuracies.append(train_accuracy)
    fold_val_accuracies.append(val_accuracy)
    fold_test_accuracies.append(test_accuracy)
    fold_precisions.append(precision)
    fold_recalls.append(recall)
    fold_f1_scores.append(f1)
    fold_roc_aucs.append(roc_auc)



    # Extraer los valores de TP, FP, FN y TN de la matriz de confusión
    TP = conf_matrix[0, 0]  # True Positives
    FP = conf_matrix[0, 1]  # False Positives
    FN = conf_matrix[1, 0]  # False Negatives
    TN = conf_matrix[1, 1]  # True Negatives

    # Calcular el score del challenge
    score = (TP + TN) / (TP + TN + FP + (5 * FN))
    fold_score.append(score)


    print("\n")
    print("----------------------------------------------")
    print(f" METRICAS DE EVALUACIÓN PARA EL MODELO")
    print("----------------------------------------------")
    print(f'Accuracy on test set: {test_accuracy * 100:.5f}%')
    print(f'Loss on test set: {test_loss * 100:.5f}%')
    print(f'Precision on test set: {precision * 100:.5f}%')
    print(f'Recall on test set: {recall * 100:.5f}%')
    print(f'F1 Score on test set: {f1 * 100:.5f}%')
    print(f'ROC AUC score on test set: {roc_auc * 100:.5f}')
    print(f'El Score oficial del Challenge es: {score * 100:.5f}')
    #######
    print("\n")
    print("----------------------------------------------")
    print(" REPORTE DE MÉTRICAS CON CLASES BALANCEADAS PARA EL MODELO")
    print("----------------------------------------------")
    report=classification_report(y_true_binary,y_pred_binary)
    print(report)


    #######
    print("\n")
    print("----------------------------------------------")
    print(" GRÁFICAS DE EVALUACIÓN")
    print("----------------------------------------------")
    # Graficar curvas de pérdida y precisión
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend()
    plt.title('Loss Curves')
    plt.show()
    print("\n")
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.legend()
    plt.title('Accuracy Curves')
    plt.show()
    print("\n")
    # Plotear la matriz de confusión
    disp = ConfusionMatrixDisplay(conf_matrix)
    disp.plot(cmap=plt.cm.Blues, values_format='d')
    plt.title('Matriz de Confusión')
    plt.show()
    print("\n")
    # Curva ROC
    fpr, tpr, thresholds = roc_curve(y_true_binary, y_pred_probs)
    roc_auc = auc(fpr, tpr)

    plt.figure(figsize=(8, 8))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.5f})'.format(roc_auc))
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.show()


print("\n")
print("----------------------------------------------")
print(" METRICAS DE EVALUACIÓN FINALES EN CADA FOLD")
print("----------------------------------------------")
print("\n")
print(" PARA ENTRENAMIENTO ")
print('El accuracy de cada fold es: ',fold_train_accuracies)
Media_TRAIN = np.mean(fold_train_accuracies)
print(f'La Media del accuracy de los k fols es: {Media_TRAIN}')
Desv_std_TRAIN = np.std(fold_train_accuracies)
print(f'La Desviación Estandar del accuracy de los k fols es: {Desv_std_TRAIN}')

Min_TRAIN = Media_TRAIN - Desv_std_TRAIN
Max_TRAIN = Media_TRAIN + Desv_std_TRAIN
print(f'El accuracy mínimo es: {Min_TRAIN}')
print(f'El accuracy máximo es: {Max_TRAIN}')

print("\n")
print(" PARA VALIDACIÓN ")
print('El accuracy de cada fold es: ',fold_val_accuracies)
Media_VAL = np.mean(fold_val_accuracies)
print(f'La Media del accuracy de los k fols es: {Media_VAL}')
Desv_std_VAL = np.std(fold_val_accuracies)
print(f'La Desviación Estandar del accuracy de los k fols es: {Desv_std_VAL}')

Min_VAL = Media_VAL - Desv_std_VAL
Max_VAL = Media_VAL + Desv_std_VAL
print(f'El accuracy mínimo es: {Min_VAL}')
print(f'El accuracy máximo es: {Max_VAL}')

print("\n")
print(" PARA TESTEO ")
print('El accuracy de cada fold es: ',fold_test_accuracies)
Media_TEST= np.mean(fold_test_accuracies)
print(f'La Media del accuracy de los k fols es: {Media_TEST}')
Desv_std_TEST = np.std(fold_test_accuracies)
print(f'La Desviación Estandar del accuracy de los k fols es: {Desv_std_TEST}')

Min_TEST = Media_TEST - Desv_std_TEST
Max_TEST = Media_TEST + Desv_std_TEST
print(f'El accuracy mínimo es: {Min_TEST}')
print(f'El accuracy máximo es: {Max_TEST}')


print("\n")
print(" PARA LA MÉTRICA DE PRECISIÓN ")
print('La precisión cada fold es: ',fold_precisions)
mean_precision = np.mean(fold_precisions)
print(f'La Media de la precisión de los k fols es: {mean_precision}')
std_precision = np.std(fold_precisions)
print(f'La Desviación Estandar de la precisión de los k fols es: {std_precision}')
Min_precision = mean_precision - std_precision
Max_precision = mean_precision + std_precision
print(f'La precisión mínima es: {Min_precision}')
print(f'La precisión máxima es: {Max_precision}')


print("\n")
print(" PARA LA MÉTRICA DE RECALL ")
print('El recall de cada fold es: ',fold_recalls)
mean_recall = np.mean(fold_recalls)
print(f'La Media del recall de los k fols es: {mean_recall}')
std_recall = np.std(fold_recalls)
print(f'La Desviación Estandar del recall de los k fols es: {std_recall}')
Min_recall = mean_recall - std_recall
Max_recall = mean_recall + std_recall
print(f'El Recall mínimo es: {Min_recall}')
print(f'El Recall máximo es: {Max_recall}')


print("\n")
print(" PARA LA MÉTRICA DE F1 SCORE ")
print('El F1 SCORE de cada fold es: ',fold_f1_scores)
mean_f1_score = np.mean(fold_f1_scores)
print(f'La Media del F1 SCORE de los k fols es: {mean_f1_score}')
std_f1_score = np.std(fold_f1_scores)
print(f'La Desviación Estandar del F1 SCORE de los k fols es: {std_f1_score}')
Min_f1_score = mean_f1_score - std_f1_score
Max_f1_score = mean_f1_score + std_f1_score
print(f'El F1 SCORE mínimo es: {Min_f1_score}')
print(f'El F1 SCORE máximo es: {Max_f1_score}')


print("\n")
print(" PARA EL ROC SCORE ")
print('El ROC SCORE de cada fold es: ',fold_roc_aucs)
mean_roc_auc = np.mean(fold_roc_aucs)
print(f'La Media del ROC SCORE de los k fols es: {mean_roc_auc}')
std_roc_auc = np.std(fold_roc_aucs)
print(f'La Desviación Estandar del ROC SCORE de los k fols es: {std_roc_auc}')
Min_roc_auc = mean_roc_auc - std_roc_auc
Max_roc_auc = mean_roc_auc + std_roc_auc
print(f'El ROC SCORE mínimo es: {Min_roc_auc}')
print(f'El ROC SCORE máximo es: {Max_roc_auc}')


print("\n")
print(" PARA EL SCORE DEL PHYSIONET")
print('El SCORE de cada fold es: ',fold_score)
mean_score = np.mean(fold_score)
print(f'La Media del SCORE de los k fols es: {mean_score}')
std_score = np.std(fold_score)
print(f'La Desviación Estandar del SCORE de los k fols es: {std_score}')
Min_score = mean_score - std_score
Max_score = mean_score + std_score
print(f'El SCORE mínimo es: {Min_score}')
print(f'El SCORE máximo es: {Max_score}')
# Out:
# Entrenando Fold 1...
# Epoch 1/999999
# 5/5 [==============================] - 136s 9s/step - loss: 4.5782 - accuracy: 0.5704 - val_loss: 45.8462 - val_accuracy: 0.6074 - lr: 0.0010
# Epoch 2/999999
# 5/5 [==============================] - 21s 4s/step - loss: 2.2146 - accuracy: 0.6056 - val_loss: 24.2176 - val_accuracy: 0.6074 - lr: 0.0010
# Epoch 3/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.4341 - accuracy: 0.6630 - val_loss: 11.2470 - val_accuracy: 0.6074 - lr: 0.0010
# Epoch 4/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.2798 - accuracy: 0.6556 - val_loss: 3.8438 - val_accuracy: 0.6074 - lr: 0.0010
# Epoch 5/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.2995 - accuracy: 0.6519 - val_loss: 3.4575 - val_accuracy: 0.6222 - lr: 0.0010
# Epoch 6/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.1959 - accuracy: 0.6870 - val_loss: 3.3579 - val_accuracy: 0.6296 - lr: 0.0010
# Epoch 7/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.2055 - accuracy: 0.6722 - val_loss: 4.9703 - val_accuracy: 0.6148 - lr: 0.0010
# Epoch 8/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.1725 - accuracy: 0.7315 - val_loss: 4.2148 - val_accuracy: 0.6148 - lr: 0.0010
# Epoch 9/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.1573 - accuracy: 0.7278 - val_loss: 3.6766 - val_accuracy: 0.6148 - lr: 0.0010
# Epoch 10/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.1633 - accuracy: 0.7278 - val_loss: 2.9297 - val_accuracy: 0.6296 - lr: 0.0010
# Epoch 11/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.1085 - accuracy: 0.7463 - val_loss: 2.5975 - val_accuracy: 0.6296 - lr: 0.0010
# Epoch 12/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.1097 - accuracy: 0.7556 - val_loss: 2.4599 - val_accuracy: 0.6222 - lr: 0.0010
# Epoch 13/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.1085 - accuracy: 0.7500 - val_loss: 2.4877 - val_accuracy: 0.6296 - lr: 0.0010
# Epoch 14/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.1037 - accuracy: 0.7463 - val_loss: 2.1412 - val_accuracy: 0.6444 - lr: 0.0010
# Epoch 15/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.0989 - accuracy: 0.7537 - val_loss: 2.0567 - val_accuracy: 0.6370 - lr: 0.0010
# Epoch 16/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1
999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9569 - accuracy: 0.8444 - val_loss: 1.3474 - val_accuracy: 0.7259 - lr: 2.0000e-04
# Epoch 41/999999
# 5/5 [==============================] - ETA: 0s - loss: 0.9371 - accuracy: 0.8574
# Epoch 41: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 5/5 [==============================] - 21s 4s/step - loss: 0.9371 - accuracy: 0.8574 - val_loss: 1.2945 - val_accuracy: 0.7481 - lr: 2.0000e-04
# Epoch 42/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9088 - accuracy: 0.8593 - val_loss: 1.2921 - val_accuracy: 0.7481 - lr: 4.0000e-05
# Epoch 43/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9151 - accuracy: 0.8500 - val_loss: 1.2943 - val_accuracy: 0.7556 - lr: 4.0000e-05
# Epoch 44/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9011 - accuracy: 0.8519 - val_loss: 1.2892 - val_accuracy: 0.7556 - lr: 4.0000e-05
# Epoch 45/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9370 - accuracy: 0.8463 - val_loss: 1.2815 - val_accuracy: 0.7556 - lr: 4.0000e-05
# Epoch 46/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9109 - accuracy: 0.8722 - val_loss: 1.2711 - val_accuracy: 0.7630 - lr: 4.0000e-05
# Epoch 47/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8780 - accuracy: 0.8759 - val_loss: 1.2638 - val_accuracy: 0.7704 - lr: 4.0000e-05
# Epoch 48/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8941 - accuracy: 0.8796 - val_loss: 1.2552 - val_accuracy: 0.7630 - lr: 4.0000e-05
# Epoch 49/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9268 - accuracy: 0.8463 - val_loss: 1.2473 - val_accuracy: 0.7556 - lr: 4.0000e-05
# Epoch 50/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9205 - accuracy: 0.8648 - val_loss: 1.2352 - val_accuracy: 0.7630 - lr: 4.0000e-05
# Epoch 51/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8929 - accuracy: 0.8778 - val_loss: 1.2281 - val_accuracy: 0.7630 - lr: 4.0000e-05
# Epoch 52/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9089 - accuracy: 0.8574 - val_loss: 1.2318 - val_accuracy: 0.7630 - lr: 4.0000e-05
# Epoch 53/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9149 - accuracy: 0.8519 - val_loss: 1.2400 - val_accuracy: 0.7704 - lr: 4.0000e-05
# Epoch 54/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9093 - accuracy: 0.8500 - val_loss: 1.2343 - val_accuracy: 0.7704 - lr: 4.0000e-05
# Epoch 55/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9248 - accuracy: 0.8685 - val_loss: 1.2249 - val_accuracy: 0.7630 - lr: 4.0000e-05
# Epoch 56/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9039 - accuracy: 0.8704 - val_loss: 1.2235 - val_accuracy: 0.7630 - lr: 4.0000e-05
# Epoch 57/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9037 - accuracy: 0.8574 - val_loss: 1.2222 - val_accuracy: 0.7630 - lr: 4.0000e-05
# Epoch 58/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9090 - accuracy: 0.8593 - val_loss: 1.2272 - val_accuracy: 0.7630 - lr: 4.0000e-05
# Epoch 59/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9031 - accuracy: 0.8481 - val_loss: 1.2314 - val_accuracy: 0.7704 - lr: 4.0000e-05
# Epoch 60/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9048 - accuracy: 0.8648 - val_loss: 1.2281 - val_accuracy: 0.7704 - lr: 4.0000e-05
# Epoch 61/999999
# 5/5 [==============================] - ETA: 0s - loss: 0.9089 - accuracy: 0.8556
# Epoch 61: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 5/5 [==============================] - 21s 4s/step - loss: 0.9089 - accuracy: 0.8556 - val_loss: 1.2272 - val_accuracy: 0.7704 - lr: 4.0000e-05
# Epoch 62/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.
999999
# 5/5 [==============================] - ETA: 0s - loss: 0.9021 - accuracy: 0.8704
# Epoch 186: ReduceLROnPlateau reducing learning rate to 1.3107200431082805e-15.
# 5/5 [==============================] - 21s 4s/step - loss: 0.9021 - accuracy: 0.8704 - val_loss: 1.1969 - val_accuracy: 0.7407 - lr: 6.5536e-15
# Epoch 187/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8944 - accuracy: 0.8519 - val_loss: 1.1968 - val_accuracy: 0.7407 - lr: 1.3107e-15
# Epoch 188/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8807 - accuracy: 0.8630 - val_loss: 1.1969 - val_accuracy: 0.7407 - lr: 1.3107e-15
# Epoch 189/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9218 - accuracy: 0.8611 - val_loss: 1.1967 - val_accuracy: 0.7407 - lr: 1.3107e-15
# Epoch 190/999999
# 5/5 [==============================] - ETA: 0s - loss: 0.8827 - accuracy: 0.8500
# Epoch 190: ReduceLROnPlateau reducing learning rate to 2.6214401285682084e-16.
# 5/5 [==============================] - 21s 4s/step - loss: 0.8827 - accuracy: 0.8500 - val_loss: 1.1968 - val_accuracy: 0.7407 - lr: 1.3107e-15
# Epoch 191/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8865 - accuracy: 0.8815 - val_loss: 1.1969 - val_accuracy: 0.7407 - lr: 2.6214e-16
# Epoch 192/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9041 - accuracy: 0.8556 - val_loss: 1.1969 - val_accuracy: 0.7407 - lr: 2.6214e-16
# Epoch 193/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8869 - accuracy: 0.8593 - val_loss: 1.1971 - val_accuracy: 0.7407 - lr: 2.6214e-16
# Epoch 194/999999
# 5/5 [==============================] - ETA: 0s - loss: 0.8756 - accuracy: 0.8852
# Epoch 194: ReduceLROnPlateau reducing learning rate to 5.2428803630155353e-17.
# 5/5 [==============================] - 21s 4s/step - loss: 0.8756 - accuracy: 0.8852 - val_loss: 1.1972 - val_accuracy: 0.7407 - lr: 2.6214e-16
# Epoch 195/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8884 - accuracy: 0.8722 - val_loss: 1.1972 - val_accuracy: 0.7407 - lr: 5.2429e-17
# Epoch 196/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8964 - accuracy: 0.8648 - val_loss: 1.1971 - val_accuracy: 0.7407 - lr: 5.2429e-17
# Epoch 197/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9100 - accuracy: 0.8667 - val_loss: 1.1971 - val_accuracy: 0.7407 - lr: 5.2429e-17
# Epoch 198/999999
# 5/5 [==============================] - ETA: 0s - loss: 0.9270 - accuracy: 0.8648
# Epoch 198: ReduceLROnPlateau reducing learning rate to 1.0485760990728867e-17.
# 5/5 [==============================] - 21s 4s/step - loss: 0.9270 - accuracy: 0.8648 - val_loss: 1.1969 - val_accuracy: 0.7407 - lr: 5.2429e-17
# Epoch 199/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8847 - accuracy: 0.8704 - val_loss: 1.1969 - val_accuracy: 0.7407 - lr: 1.0486e-17
# Epoch 200/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8812 - accuracy: 0.8704 - val_loss: 1.1972 - val_accuracy: 0.7407 - lr: 1.0486e-17
# Epoch 201/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9103 - accuracy: 0.8667 - val_loss: 1.1972 - val_accuracy: 0.7407 - lr: 1.0486e-17
# Epoch 202/999999
# 5/5 [==============================] - ETA: 0s - loss: 0.8730 - accuracy: 0.8796
# Epoch 202: ReduceLROnPlateau reducing learning rate to 2.097152165058549e-18.
# 5/5 [==============================] - 21s 4s/step - loss: 0.8730 - accuracy: 0.8796 - val_loss: 1.1973 - val_accuracy: 0.7407 - lr: 1.0486e-17
# Epoch 203/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8758 - accuracy: 0.8852 - val_loss: 1.1973 - val_accuracy: 0.7407 - lr: 2.0972e-18
# Epoch 204/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9041 - accuracy: 0.8593 - val_loss: 1.1973 - val_accuracy: 0.7407 - lr: 2.0972e-18
# Epoch 205/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9100 - accuracy: 0.8611 - val_loss: 1.1972 - val_accuracy: 0.7407 - lr: 2.0972e-18
# Epoch 206/999999
# 5/5 [==============================] - ETA: 0s - loss: 0.8959 - accuracy: 0.8796
# Epoch 206: ReduceLROnPlateau reducing learning rate to 4.19430449555322e-19.
# 5/5 [==============================] - 21s 4s/step - loss: 0.8959 - accuracy: 0.8796 - val_loss: 1.1971 - val_accuracy: 0.7407 - lr: 2.0972e-18
# Epoch 207/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9017 - accuracy: 0.8593 - val_loss: 1.1970 - val_accuracy: 0.7407 - lr: 4.1943e-19
# Epoch 208/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8787 - accuracy: 0.8833 - val_loss: 1.1970 - val_accuracy: 0.7407 - lr: 4.1943e-19
# Epoch 209/999999
# 5/5 [==============================] - ETA: 0s - loss: 0.9082 - accuracy: 0.8648Restoring model weights from the end of the best epoch: 189.
# 5/5 [==============================] - 21s 4s/step - loss: 0.9082 - accuracy: 0.8648 - val_loss: 1.1969 - val_accuracy: 0.7407 - lr: 4.1943e-19
# Epoch 209: early stopping
# 3/3 [==============================] - 7s 958ms/step - loss: 1.3813 - accuracy: 0.6800
# 17/17 [==============================] - 6s 357ms/step - loss: 0.7716 - accuracy: 0.9630
# 5/5 [==============================] - 2s 294ms/step - loss: 1.1967 - accuracy: 0.7407
# 3/3 [==============================] - 1s 351ms/step
#
#
# ----------------------------------------------
#  METRICAS DE EVALUACIÓN PARA EL MODELO
# ----------------------------------------------
# Accuracy on test set: 68.00000%
# Loss on test set: 138.12512%
# Precision on test set: 59.25926%
# Recall on test set: 55.17241%
# F1 Score on test set: 57.14286%
# ROC AUC score on test set: 70.53973
# El Score oficial del Challenge es: 42.85714
#
#
# ----------------------------------------------
#  REPORTE DE MÉTRICAS CON CLASES BALANCEADAS PARA EL MODELO
# ----------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.76      0.74        46
#            1       0.59      0.55      0.57        29
#
#     accuracy                           0.68        75
#    macro avg       0.66      0.66      0.66        75
# weighted avg       0.68      0.68      0.68        75
#
#
#
# ----------------------------------------------
#  GRÁFICAS DE EVALUACIÓN
# ----------------------------------------------
# Entrenando Fold 2...
# Epoch 1/999999
# 5/5 [==============================] - 29s 4s/step - loss: 4.1050 - accuracy: 0.5796 - val_loss: 37.6049 - val_accuracy: 0.6074 - lr: 0.0010
# Epoch 2/999999
# 5/5 [==============================] - 22s 4s/step - loss: 2.2391 - accuracy: 0.5796 - val_loss: 20.0519 - val_accuracy: 0.6074 - lr: 0.0010
# Epoch 3/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.6384 - accuracy: 0.6537 - val_loss: 12.6846 - val_accuracy: 0.6074 - lr: 0.0010
# Epoch 4/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.4540 - accuracy: 0.6704 - val_loss: 4.3284 - val_accuracy: 0.5852 - lr: 0.0010
# Epoch 5/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.2507 - accuracy: 0.6778 - val_loss: 4.5722 - val_accuracy: 0.6074 - lr: 0.0010
# Epoch 6/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.2486 - accuracy: 0.7074 - val_loss: 3.6942 - val_accuracy: 0.6222 - lr: 0.0010
# Epoch 7/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.1423 - accuracy: 0.7278 - val_loss: 4.2110 - val_accuracy: 0.5852 - lr: 0.0010
# Epoch 8/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.1302 - accuracy: 0.7241 - val_loss: 3.9980 - val_accuracy: 0.6074 - lr: 0.0010
# Epoch 9/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.0862 - accuracy: 0.7463 - val_loss: 4.2508 - val_accuracy: 0.6074 - lr: 0.0010
# Epoch 10/999999
# 5/5 [==============================] - ETA: 0s - loss: 1.0426 - accuracy: 0.7685
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 5/5 [==============================] - 21s 4s/step - loss: 1.0426 - accuracy: 0.7685 - val_loss: 4.2094 - val_accuracy: 0.6074 - lr: 0.0010
# Epoch 11/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.0533 - accuracy: 0.7704 - val_loss: 3.7400 - val_accuracy: 0.6074 - lr: 2.0000e-04
# Epoch 12/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.0552 - accuracy: 0.7926 - val_loss: 3.7744 - val_accuracy: 0.6074 - lr: 2.0000e-04
# Epoch 13/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.0169 - accuracy: 0.8019 - val_loss: 3.5657 - val_accuracy: 0.6074 - lr: 2.0000e-04
# Epoch 14/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.0247 - accuracy: 0.7722 - val_loss: 3.1677 - val_accuracy: 0.6074 - lr: 2.0000e-04
# Epoch 15/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.0291 - accuracy: 0.7796 - val_loss: 2.8856 - val_accuracy: 0.6074 - lr: 2.0000e-04
# Epoch 16/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9936 - accuracy: 0.8019 - val_loss: 2.7642 - val_accuracy: 0.6074 - lr: 2.0000e-04
# Epoch 17/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.0101 - accuracy: 0.8093 - val_loss: 2.4853 - val_accuracy: 0.5926 - lr: 2.0000e-04
# Epoch 18/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9877 - accuracy: 0.8074 - val_loss: 2.3045 - val_accuracy: 0.6074 - lr: 2.0000e-04
# Epoch 19/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9985 - accuracy: 0.8056 - val_loss: 2.2559 - val_accuracy: 0.6222 - lr: 2.0000e-04
# Epoch 20/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9872 - accuracy: 0.8148 - val_loss: 2.1897 - val_accuracy: 0.6222 - lr: 2.0000e-04
# Epoch 21/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.0142 - accuracy: 0.7907 - val_loss: 2.1766 - val_accuracy: 0.6148 - lr: 2.0000e-04
# Epoch 22/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.0134 - accuracy: 0.8130 - val_loss: 2.3055 - val_accuracy: 0.6148 - lr: 2.0000e-04
# Epoch 23/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9645 - accuracy: 0.8204 - val_loss: 2.2417 - val_accuracy: 0.6074 - lr: 2.0000e-04
# Epoch 24/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9738 - accuracy: 0.8130 - val_loss: 2.0704 - val_accuracy: 0.6148 - lr: 2.0000e-04
# Epoch 25/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9649 - accuracy: 0.8185 - val_loss: 2.1090 - val_accuracy: 0.6000 - lr: 2.0000e-04
# Epoch 26/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9796 - accuracy: 0.8222 - val_loss: 2.1508 - val_accuracy: 0.6000 - lr: 2.0000e-04
# Epoch 27/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9550 - accuracy: 0.8037 - val_loss: 1.9271 - val_accuracy: 0.6296 - lr: 2.0000e-04
# Epoch 28/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9452 - accuracy: 0.8315 - val_loss: 1.7903 - val_accuracy: 0.6296 - lr: 2.0000e-04
# Epoch 29/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9622 - accuracy: 0.8241 - val_loss: 1.7781 - val_accuracy: 0.6296 - lr: 2.0000e-04
# Epoch 30/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9430 - accuracy: 0.8333 - val_loss: 1.8298 - val_accuracy: 0.6148 - lr: 2.0000e-04
# Epoch 31/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9285 - accuracy: 0.8315 - val_loss: 1.7995 - val_accuracy: 0.6222 - lr: 2.0000e-04
# Epoch 32/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9417 - accuracy: 0.8389 - val_loss: 1.7506 - val_accuracy: 0.6444 - lr: 2.0000e-04
# Epoch 33/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9329 - accuracy: 0.8278 - val_loss: 1.7705 - val_accuracy: 0.6296 - lr: 2.0000e-04
# Epoch 34/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9383 - accuracy: 0.8333 - val_loss: 1.8122 - val_accuracy: 0.6296 - lr: 2.0000e-04
# Epoch 35/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9095 - accuracy: 0.8556 - val_loss: 1.8210 - val_accuracy: 0.6222 - lr: 2.0000e-04
# Epoch 36/999999
# 5/5 [==============================] - ETA: 0s - loss: 0.9259 - accuracy: 0.8370
# Epoch 36: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 5/5 [==============================] - 21s 4s/step - loss: 0.9259 - accuracy: 0.8370 - val_loss: 1.7847 - val_accuracy: 0.6370 - lr: 2.0000e-04
# Epoch 37/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9030 - accuracy: 0.8370 - val_loss: 1.7652 - val_accuracy: 0.6519 - lr: 4.0000e-05
# Epoch 38/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9009 - accuracy: 0.8685 - val_loss: 1.7443 - val_accuracy: 0.6519 - lr: 4.0000e-05
# Epoch 39/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9220 - accuracy: 0.8463 - val_loss: 1.7203 - val_accuracy: 0.6519 - lr: 4.0000e-05
# Epoch 40/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9282 - accuracy: 0.8407 - val_loss: 1.7138 - val_accuracy: 0.6519 - lr: 4.0000e-05
# Epoch 41/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9324 - accuracy: 0.8315 - val_loss: 1.7046 - val_accuracy: 0.6519 - lr: 4.0000e-05
# Epoch 42/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9030 - accuracy: 0.8500 - val_loss: 1.6922 - val_accuracy: 0.6519 - lr: 4.0000e-05
# Epoch 43/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8976 - accuracy: 0.8574 - val_loss: 1.6769 - val_accuracy: 0.6519 - lr: 4.0000e-05
# Epoch 44/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9173 - accuracy: 0.8407 - val_loss: 1.6661 - val_accuracy: 0.6519 - lr: 4.0000e-05
# Epoch 45/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8946 - accuracy: 0.8481 - val_loss: 1.6474 - val_accuracy: 0.6444 - lr: 4.0000e-05
# Epoch 46/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8932 - accuracy: 0.8537 - val_loss: 1.6333 - val_accuracy: 0.6667 - lr: 4.0000e-05
# Epoch 47/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8819 - accuracy: 0.8667 - val_loss: 1.6166 - val_accuracy: 0.6667 - lr: 4.0000e-05
# Epoch 48/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9074 - accuracy: 0.8389 - val_loss: 1.6208 - val_accuracy: 0.6667 - lr: 4.0000e-05
# Epoch 49/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8971 - accuracy: 0.8611 - val_loss: 1.6198 - val_accuracy: 0.6593 - lr: 4.0000e-05
# Epoch 50/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8938 - accuracy: 0.8537 - val_loss: 1.6149 - val_accuracy: 0.6667 - lr: 4.0000e-05
# Epoch 51/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8957 - accuracy: 0.8556 - val_loss: 1.6002 - val_accuracy: 0.6667 - lr: 4.0000e-05
# Epoch 52/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8839 - accuracy: 0.8611 - val_loss: 1.5849 - val_accuracy: 0.6593 - lr: 4.0000e-05
# Epoch 53/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9279 - accuracy: 0.8370 - val_loss: 1.5720 - val_accuracy: 0.6667 - lr: 4.0000e-05
# Epoch 54/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9064 - accuracy: 0.8611 - val_loss: 1.5622 - val_accuracy: 0.6667 - lr: 4.0000e-05
# Epoch 55/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8951 - accuracy: 0.8667 - val_loss: 1.5586 - val_accuracy: 0.6667 - lr: 4.0000e-05
# Epoch 56/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8874 - accuracy: 0.8741 - val_loss: 1.5583 - val_accuracy: 0.6667 - lr: 4.0000e-05
# Epoch 57/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9102 - accuracy: 0.8556 - val_loss: 1.5609 - val_accuracy: 0.6593 - lr: 4.0000e-05
# Epoch 58/999999
# ...
# Epoch 4/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.4753 - accuracy: 0.6574 - val_loss: 5.8776 - val_accuracy: 0.5704 - lr: 0.0010
# Epoch 5/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.3166 - accuracy: 0.6556 - val_loss: 4.4011 - val_accuracy: 0.5778 - lr: 0.0010
# Epoch 6/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.2657 - accuracy: 0.7000 - val_loss: 3.4303 - val_accuracy: 0.6148 - lr: 0.0010
# Epoch 7/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.2476 - accuracy: 0.7056 - val_loss: 3.2971 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 8/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.2333 - accuracy: 0.6944 - val_loss: 3.6635 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 9/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.1067 - accuracy: 0.7315 - val_loss: 4.4759 - val_accuracy: 0.6148 - lr: 0.0010
# Epoch 10/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.1752 - accuracy: 0.7593 - val_loss: 3.6487 - val_accuracy: 0.6000 - lr: 0.0010
# Epoch 11/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.0858 - accuracy: 0.7741 - val_loss: 2.5707 - val_accuracy: 0.6074 - lr: 0.0010
# Epoch 12/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.1228 - accuracy: 0.7500 - val_loss: 2.4434 - val_accuracy: 0.6074 - lr: 0.0010
# Epoch 13/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.1013 - accuracy: 0.7630 - val_loss: 2.1701 - val_accuracy: 0.6444 - lr: 0.0010
# Epoch 14/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.0882 - accuracy: 0.7722 - val_loss: 2.5522 - val_accuracy: 0.6148 - lr: 0.0010
# Epoch 15/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.0726 - accuracy: 0.7778 - val_loss: 2.6416 - val_accuracy: 0.6074 - lr: 0.0010
# Epoch 16/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.0032 - accuracy: 0.8130 - val_loss: 2.2607 - val_accuracy: 0.5852 - lr: 0.0010
# Epoch 17/999999
# 5/5 [==============================] - ETA: 0s - loss: 1.0355 - accuracy: 0.7852
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 5/5 [==============================] - 21s 4s/step - loss: 1.0355 - accuracy: 0.7852 - val_loss: 2.2880 - val_accuracy: 0.6074 - lr: 0.0010
# Epoch 18/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.0259 - accuracy: 0.8019 - val_loss: 2.0558 - val_accuracy: 0.6222 - lr: 2.0000e-04
# Epoch 19/999999
# 5/5 [==============================] - 21s 4s/step - loss: 1.0132 - accuracy: 0.8259 - val_loss: 1.8859 - val_accuracy: 0.6370 - lr: 2.0000e-04
# Epoch 20/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9774 - accuracy: 0.8333 - val_loss: 1.8673 - val_accuracy: 0.6296 - lr: 2.0000e-04
# Epoch 21/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9802 - accuracy: 0.8296 - val_loss: 1.8587 - val_accuracy: 0.6296 - lr: 2.0000e-04
# Epoch 22/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9721 - accuracy: 0.8259 - val_loss: 1.8311 - val_accuracy: 0.6370 - lr: 2.0000e-04
# Epoch 23/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9622 - accuracy: 0.8278 - val_loss: 1.7648 - val_accuracy: 0.6148 - lr: 2.0000e-04
# Epoch 24/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9352 - accuracy: 0.8315 - val_loss: 1.7203 - val_accuracy: 0.6296 - lr: 2.0000e-04
# Epoch 25/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9627 - accuracy: 0.8333 - val_loss: 1.6811 - val_accuracy: 0.6222 - lr: 2.0000e-04
# Epoch 26/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9590 - accuracy: 0.8352 - val_loss: 1.6634 - val_accuracy: 0.6222 - lr: 2.0000e-04
# Epoch 27/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9552 - accuracy: 0.8500 - val_loss: 1.6421 - val_accuracy: 0.6222 - lr: 2.0000e-04
# Epoch 28/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9336 - accuracy: 0.8648 - val_loss: 1.6379 - val_accuracy: 0.6296 - lr: 2.0000e-04
# Epoch 29/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9480 - accuracy: 0.8481 - val_loss: 1.6315 - val_accuracy: 0.6370 - lr: 2.0000e-04
# Epoch 30/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9188 - accuracy: 0.8556 - val_loss: 1.6250 - val_accuracy: 0.6444 - lr: 2.0000e-04
# Epoch 31/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9114 - accuracy: 0.8389 - val_loss: 1.6227 - val_accuracy: 0.6370 - lr: 2.0000e-04
# Epoch 32/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9457 - accuracy: 0.8426 - val_loss: 1.6146 - val_accuracy: 0.6370 - lr: 2.0000e-04
# Epoch 33/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9145 - accuracy: 0.8556 - val_loss: 1.6156 - val_accuracy: 0.6296 - lr: 2.0000e-04
# Epoch 34/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9011 - accuracy: 0.8648 - val_loss: 1.6020 - val_accuracy: 0.6296 - lr: 2.0000e-04
# Epoch 35/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9289 - accuracy: 0.8389 - val_loss: 1.5961 - val_accuracy: 0.6148 - lr: 2.0000e-04
# Epoch 36/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9148 - accuracy: 0.8500 - val_loss: 1.5955 - val_accuracy: 0.6148 - lr: 2.0000e-04
# Epoch 37/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9038 - accuracy: 0.8759 - val_loss: 1.5671 - val_accuracy: 0.6519 - lr: 2.0000e-04
# Epoch 38/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9071 - accuracy: 0.8537 - val_loss: 1.5574 - val_accuracy: 0.6444 - lr: 2.0000e-04
# Epoch 39/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9229 - accuracy: 0.8444 - val_loss: 1.5566 - val_accuracy: 0.6519 - lr: 2.0000e-04
# Epoch 40/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8886 - accuracy: 0.8648 - val_loss: 1.5545 - val_accuracy: 0.6148 - lr: 2.0000e-04
# Epoch 41/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9011 - accuracy: 0.8574 - val_loss: 1.5620 - val_accuracy: 0.6000 - lr: 2.0000e-04
# Epoch 42/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8957 - accuracy: 0.8685 - val_loss: 1.5047 - val_accuracy: 0.6222 - lr: 2.0000e-04
# Epoch 43/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9131 - accuracy: 0.8704 - val_loss: 1.4929 - val_accuracy: 0.6444 - lr: 2.0000e-04
# Epoch 44/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8706 - accuracy: 0.8722 - val_loss: 1.5087 - val_accuracy: 0.6593 - lr: 2.0000e-04
# Epoch 45/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8865 - accuracy: 0.8833 - val_loss: 1.5402 - val_accuracy: 0.6148 - lr: 2.0000e-04
# Epoch 46/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.9231 - accuracy: 0.8481 - val_loss: 1.5633 - val_accuracy: 0.5852 - lr: 2.0000e-04
# Epoch 47/999999
# 5/5 [==============================] - ETA: 0s - loss: 0.8737 - accuracy: 0.8667
# Epoch 47: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 5/5 [==============================] - 21s 4s/step - loss: 0.8737 - accuracy: 0.8667 - val_loss: 1.5826 - val_accuracy: 0.5852 - lr: 2.0000e-04
# Epoch 48/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8714 - accuracy: 0.8907 - val_loss: 1.5863 - val_accuracy: 0.5778 - lr: 4.0000e-05
# Epoch 49/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8562 - accuracy: 0.8926 - val_loss: 1.5882 - val_accuracy: 0.5778 - lr: 4.0000e-05
# Epoch 50/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8668 - accuracy: 0.8778 - val_loss: 1.5934 - val_accuracy: 0.5778 - lr: 4.0000e-05
# Epoch 51/999999
# 5/5 [==============================] - ETA: 0s - loss: 0.8838 - accuracy: 0.8778
# Epoch 51: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 5/5 [==============================] - 21s 4s/step - loss: 0.8838 - accuracy: 0.8778 - val_loss: 1.5978 - val_accuracy: 0.5852 - lr: 4.0000e-05
# Epoch 52/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8602 - accuracy: 0.8852 - val_loss: 1.5943 - val_accuracy: 0.5852 - lr: 8.0000e-06
# Epoch 53/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8736 - accuracy: 0.8759 - val_loss: 1.5900 - val_accuracy: 0.5852 - lr: 8.0000e-06
# Epoch 54/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8650 - accuracy: 0.8852 - val_loss: 1.5858 - val_accuracy: 0.5852 - lr: 8.0000e-06
# Epoch 55/999999
# 5/5 [==============================] - ETA: 0s - loss: 0.8848 - accuracy: 0.8648
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 5/5 [==============================] - 21s 4s/step - loss: 0.8848 - accuracy: 0.8648 - val_loss: 1.5817 - val_accuracy: 0.5852 - lr: 8.0000e-06
# Epoch 56/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8616 - accuracy: 0.8870 - val_loss: 1.5788 - val_accuracy: 0.5852 - lr: 1.6000e-06
# Epoch 57/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8550 - accuracy: 0.9019 - val_loss: 1.5763 - val_accuracy: 0.5852 - lr: 1.6000e-06
# Epoch 58/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8671 - accuracy: 0.8741 - val_loss: 1.5748 - val_accuracy: 0.5852 - lr: 1.6000e-06
# Epoch 59/999999
# 5/5 [==============================] - ETA: 0s - loss: 0.8432 - accuracy: 0.8796
# Epoch 59: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 5/5 [==============================] - 21s 4s/step - loss: 0.8432 - accuracy: 0.8796 - val_loss: 1.5717 - val_accuracy: 0.5852 - lr: 1.6000e-06
# Epoch 60/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8620 - accuracy: 0.8981 - val_loss: 1.5697 - val_accuracy: 0.5852 - lr: 3.2000e-07
# Epoch 61/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8562 - accuracy: 0.8944 - val_loss: 1.5679 - val_accuracy: 0.5926 - lr: 3.2000e-07
# Epoch 62/999999
# 5/5 [==============================] - 21s 4s/step - loss: 0.8724 - accuracy: 0.8815 - val_loss: 1.5661 - val_accuracy: 0.5926 - lr: 3.2000e-07
# Epoch 63/999999
# 5/5 [==============================] - ETA: 0s - loss: 0.8589 - accuracy: 0.8870Restoring model weights from the end of the best epoch: 43.
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 5/5 [==============================] - 21s 4s/step - loss: 0.8589 - accuracy: 0.8870 - val_loss: 1.5641 - val_accuracy: 0.5926 - lr: 3.2000e-07
# Epoch 63: early stopping
# 3/3 [==============================] - 2s 243ms/step - loss: 1.2494 - accuracy: 0.7200
# 17/17 [==============================] - 6s 356ms/step - loss: 0.7445 - accuracy: 0.9648
# 5/5 [==============================] - 2s 294ms/step - loss: 1.4929 - accuracy: 0.6444
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ee5986b7e20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 [==============================] - 1s 350ms/step
#
#
# ----------------------------------------------
#  METRICAS DE EVALUACIÓN PARA EL MODELO
# ----------------------------------------------
# Accuracy on test set: 72.00000%
# Loss on test set: 124.93808%
# Precision on test set: 68.18182%
# Recall on test set: 51.72414%
# F1 Score on test set: 58.82353%
# ROC AUC score on test set: 73.76312
# El Score oficial del Challenge es: 52.42718
#
#
# ----------------------------------------------
#  REPORTE DE MÉTRICAS CON CLASES BALANCEADAS PARA EL MODELO
# ----------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.74      0.85      0.79        46
#            1       0.68      0.52      0.59        29
#
#     accuracy                           0.72        75
#    macro avg       0.71      0.68      0.69        75
# weighted avg       0.71      0.72      0.71        75
#
#
#
# ----------------------------------------------
#  GRÁFICAS DE EVALUACIÓN
# ----------------------------------------------
# ----------------------------------------------
#  METRICAS DE EVALUACIÓN FINALES EN CADA FOLD
# ----------------------------------------------
#
#
#  PARA ENTRENAMIENTO
# El accuracy de cada fold es:  [0.9629629850387573, 0.9629629850387573, 0.9425926208496094, 0.9425926208496094, 0.949999988079071, 0.949999988079071, 0.9611111283302307, 0.9611111283302307, 0.9648148417472839, 0.9648148417472839]
# La Media del accuracy de los k fols es: 0.9562963128089905
# La Desviación Estandar del accuracy de los k fols es: 0.008574697438597642
# El accuracy mínimo es: 0.9477216153703929
# El accuracy máximo es: 0.9648710102475881
#
#
#  PARA VALIDACIÓN
# El accuracy de cada fold es:  [0.7407407164573669, 0.7407407164573669, 0.7111111283302307, 0.7111111283302307, 0.7185184955596924, 0.7185184955596924, 0.6888889074325562, 0.6888889074325562, 0.644444465637207, 0.644444465637207]
# La Media del accuracy de los k fols es: 0.7007407426834107
# La Desviación Estandar del accuracy de los k fols es: 0.03265984723107999
# El accuracy mínimo es: 0.6680808954523307
# El accuracy máximo es: 0.7334005899144906
#
#
#  PARA TESTEO
# El accuracy de cada fold es:  [0.6800000071525574, 0.6800000071525574, 0.6133333444595337, 0.6133333444595337, 0.6399999856948853, 0.6399999856948853, 0.5866666436195374, 0.5866666436195374, 0.7200000286102295, 0.7200000286102295]
# La Media del accuracy de los k fols es: 0.6480000019073486
# La Desviación Estandar del accuracy de los k fols es: 0.04740371803513685
# El accuracy mínimo es: 0.6005962838722118
# El accuracy máximo es: 0.6954037199424855
#
#
#  PARA LA MÉTRICA DE PRECISIÓN
# La precisión cada fold es:  [0.5925925925925926, 0.5, 0.5416666666666666, 0.45454545454545453, 0.6818181818181818]
# La Media de la precisión de los k fols es: 0.554124579124579
# La Desviación Estandar de la precisión de los k fols es: 0.07846797554316483
# La precisión mínima es: 0.4756566035814142
# La precisión máxima es: 0.6325925546677439
#
#
#  PARA LA MÉTRICA DE RECALL
# El recall de cada fold es:  [0.5517241379310345, 0.5172413793103449, 0.4482758620689655, 0.3448275862068966, 0.5172413793103449]
# La Media del recall de los k fols es: 0.47586206896551725
# La Desviación Estandar del recall de los k fols es: 0.07363502242780215
# El Recall mínimo es: 0.4022270465377151
# El Recall máximo es: 0.5494970913933194
#
#
#  PARA LA MÉTRICA DE F1 SCORE
# El F1 SCORE de cada fold es:  [0.5714285714285714, 0.5084745762711865, 0.49056603773584906, 0.39215686274509803, 0.5882352941176471]
# La Media del F1 SCORE de los k fols es: 0.5101722684596705
# La Desviación Estandar del F1 SCORE de los k fols es: 0.06951416122810285
# El F1 SCORE mínimo es: 0.4406581072315676
# El F1 SCORE máximo es: 0.5796864296877733
#
#
#  PARA EL ROC SCORE
# El ROC SCORE de cada fold es:  [0.7053973013493254, 0.6176911544227887, 0.6229385307346327, 0.595952023988006, 0.7376311844077961]
# La Media del ROC SCORE de los k fols es: 0.6559220389805097
# La Desviación Estandar del ROC SCORE de los k fols es: 0.055263190427975374
# El ROC SCORE mínimo es: 0.6006588485525344
# El ROC SCORE máximo es: 0.711185229408485
#
#
#  PARA EL SCORE DEL PHYSIONET
# El SCORE de cada fold es:  [0.42857142857142855, 0.34074074074074073, 0.40336134453781514, 0.35772357723577236, 0.5242718446601942]
# La Media del SCORE de los k fols es: 0.41093378714919016
# La Desviación Estandar del SCORE de los k fols es: 0.06476470298787511
# El SCORE mínimo es: 0.34616908416131503
# El SCORE máximo es: 0.4756984901370653
